# %% [markdown]
# ## Deadline + Late Penalty
#
# $\textbf{Note:}$ It will take you quite some time to complete this project, therefore, we earnestly recommend that you start working as early as possible. You should read the specs carefully at least 2-3 times before you start coding.
#
# * $\textbf{Submission deadline for the Project (Part-2) is 20:59:59 (08:59:59 PM) on 18th Nov, 2019}$
# * $\textbf{LATE PENALTY: 10% on day-1 and 20% on each subsequent day.}$

# %% [markdown]
# ## Instructions
# 1. This note book contains instructions for $\textbf{COMP6714-Project (Part-2)}$. We have already released the instructions for the $\textbf{Part-1 of the Project}$ in a seperate notebook.
#
# * You are required to complete your implementation for part-2 in the file `project_part2.py` provided along with this notebook. Please $\textbf{DO NOT ALTER}$ the name of the file.
#
# * You are not allowed to print out unnecessary stuff. We will not consider any output printed out on the screen. All results should be returned in appropriate data structures via corresponding functions.
#
# * You can submit your implementation for **Project (Part-2)** via submission system: http://kg.cse.unsw.edu.au/submit/ . We have already sent out the invitations for you to join the submission system. In case of problems please post your request @ Piazza.
#
# * For each question, we have provided you with detailed instructions along with question headings. In case of problems, you can post your query @ Piazza.
#
# * You are allowed to add other functions and/or import modules (you may have to for this project), but you are not allowed to define global variables. **Only functions are allowed** in `project_part2.py`
#
# * You should not import unnecessary and non-standard modules/libraries. Loading such libraries at test time will lead to errors and hence ZERO score for your project. If you are not sure, please ask @ Piazza.
#
# * We will provide immediate feedback on your submission. You can access your scores using the online submission portal on the same day.
#
# * For the **Final Evaluation**, we will be using different data sets, so your final scores may vary.
#
# * You are allowed to have a limited number of Feedback Attempts $\textbf{(15 Attempts for each student)}$, we will use your **LAST** submission for Final Evaluation.
#
# ### Allowed Libraries:
#
# You are required to write your implementation for the project (part-2) using `Python 3.6.5`. You are only allowed to use the following python libraries:
# * $\textbf{spacy (v2.1.8)}$
# * $\textbf{XGBoost (v0.90)}$

# %% [markdown]
# # Q2: Named Entity Disambiguation/Named Entity Linking (20 Points)

# %% [markdown]
# For $Q2$, you are required to use your experience gained in $Q1$ (from project-part1) to solve a renowned problem in language processing, i.e., Named Entity Disambiguation (NED) aka Named Entity Linking (NEL). It aims at assigning unique identities (i.e., entities, such as Persons, Locations and Organizations etc.) to the mention (i.e., a substring/span of the sentence that refer to an **entity**) identified in the text.
#
# For example, consider the sentence: `Olympia is the captial of Washington`. The **mention** `Washington` refers to the **entity** `Washington (state)` (https://en.wikipedia.org/wiki/Washington_(state)), rather than other possible entities with similar names, such as: (i) `The Washington Post (an American daily newspaper)` (https://en.wikipedia.org/wiki/The_Washington_Post), (ii) `The George Washington (former U.S. president)` (https://en.wikipedia.org/wiki/George_Washington), etc.
#
#
#
# For this project, we provide you with the text documents with the mentions pre-idetified alongwith a list of possible candidate entities corresponding to each mention. Your task is to come up with a learning to rank model in order to disambiguate the mention, i.e., map the mention to the correct entity.
#
#
# ### Inputs:
# Input to your model are as follows. The file formats are explained in the next sub-section.
#
# 1. $men\_docs.pickle$ <br>
#    A python dictionary of the documents with mentions pre-identified.
# 2. $parsed\_candidate\_entities.pickle$ <br>
#    A dictionary containing textual description for each candidate entity (pages from Wikipedia). **Note** that we have already pre-processed and parsed the candidate entity pages for you.
# 3. $train.pickle$ <br>
#    Training data.
# 4. $train\_labels.pickle$ <br>
#    Labels corresponding to the training data.
# 5. $dev.pickle$ <br>
#    Development data. **Note:** we will use this $dev$ data to provide Feedback for $Q2$. For final evaluation, we will be using completely different $test$ data sets.
# 6. $dev\_labels.pickle$ <br>
#    Labels corresponding to the `dev` data.

# %% [markdown]
# ## File Formats
#
# ### 1. $men\_docs.pickle$
# It is a python dictionary containing the documents pertaining to the mention with $key:$ document title, $value:$ document text. Each document conatins free text.
#
# ### 2. $parsed\_candidate\_entities.pickle$
#
# It is a python dictionary storing the Wikipedia description pages for each candidate entity with:
# * $key:$ entity name,
# * $value:$ text corresponding to entity's description. We use entity's wikipedia page to capture the entity's description. Parsing large text files may take a considerable time, so we provide you with the $spacy's$ parsing results. We consider each document as a large paragraph and store the parsing results as a list of tuples, with each tuple of the form:
#
# > $(id, token, lemma, pos\text{-}tag, entity\text{-}tag)$, where <br>
#  * $id$: corresponds to a unique token id in the paragpah <br>
#  * $token$: corresponds to the original text token <br>
#  * $lemma$: corresponds to the token's lemma <br>
#  * $pos\text{-}tag$: is the token's part-of-the-speech tag <br>
#  * $entity\text{-}tag$: is the entity tag detected by the spacy.<br>
#
# For detailed descrition of the spacy's paring results, please check the following link: https://spacy.io/usage/linguistic-features
#
# A small subset of the parsed text for the entity `Cartoon_Network_Nordic` from the file $parsed\_candidate\_entities.pickle$ is as under:

# %% [raw]
# [(1, 'Cartoon', 'Cartoon', 'PROPN', 'B-ORG'),
#  (2, 'Network', 'Network', 'PROPN', 'I-ORG'),
#  (3, 'television', 'television', 'NOUN', 'O'),
#  (4, 'channel', 'channel', 'NOUN', 'O'),
#  (5, 'broadcasting', 'broadcast', 'VERB', 'O'),
#  (6, 'youth', 'youth', 'NOUN', 'O'),
#  (7, 'children', 'child', 'NOUN', 'O'),
#  (8, 'programmes', 'programme', 'NOUN', 'O'),
#  (9, 'Sweden', 'Sweden', 'PROPN', 'B-GPE'),
#  (10, 'Norway', 'Norway', 'PROPN', 'B-GPE')]

# %% [markdown]
# ### 3. $train.pickle$
# A python dictionary containing the training data. It consists of following fields: <br>
# * $key:$ A unique integer containing the mention_id,
# * $value:$ A dictionary containing the mention's description as following $key\text{-}value$ pairs:
# > * $doc\_title:$ Title of the document containing the mention. It will be one of the keys of the dictionary: $men\_docs.pickle$ <br>
#   * $mention:$ Token span within the document $doc\_title$ indicating the mention.<br>
#   * $offset:$ Mention's offset position in the document $doc\_title$<br>
#   * $length:$ Length of the mention's tokens<br>
#   * $candidate\_entities:$ A list of candidate entities corresponding to the mention. Each entity candidate corresponds to a key in the file: $parsed\_candidate\_entities.pickle$ <br>
#
# An example mention from the file $train.pikcle$ is shown below:

# %% [raw]
# {1: {'doc_title': '1_GOLF',                                   ## Mention's document title
#   'mention': 'PGA Tour',                                      ## Mention's tokens
#   'offset': 2046,                                             ## Mention's offset position in the document
#   'length': 8,                                                ## Length of mention tokens
#   'candidate_entities': ['Professional_Golfers_Association',  ## Candidate Entities for the mention
#    'PGA_Tour',
#    'Golf_Channel_on_NBC',
#    '2009_PGA_Tour',
#    '2011_PGA_Tour',
#    '2008_PGA_Tour',
#    'PGA_Tour_on_CBS']}}

# %% [markdown]
# ### 4. $train\_labels.pickle$
# A python dictionary containing the labels corresponding to the training mentions. It consists of following fields: <br>
# * $key:$ A unique integer containing the mention_id, $value:$ A dictionary containing the following key-value pairs:
# > 1. $doc\_title:$ Title of the document containing the mention. It will be one of the keys of the dictionary: $men\_docs.pickle$ <br>
#   * $mention:$ Tokens span within the document $doc\_title$ indicating the mention.<br>
#   * $label:$ Mention's Ground Truth Entity Label. It also corresponds to a key in the file: $parsed\_candidate\_entities.pickle$ <br>
#
# **Note:**, for each mention, we use the same `mention_id` for both the files: (i) $train.pickle$, and (ii) $train\_labels.pickle$.<br>
#
# An example from the file $train\_labels.pikcle$ is shown as follows:

# %% [raw]
# {1: {'doc_title': '1_GOLF',   ### Mention's document title
#   'mention': 'PGA Tour',      ### Mention's tokens
#   'label': 'PGA_Tour'}}       ### Mention's True Entity Label

# %% [markdown]
# ### 5. $dev.pickle$
# It follows the same format as that of the file: $train.pickle$
# ### 6. $dev\_labels.pickle$
# It follows the same format as the of the file: $train\_labels.pickle$
#
# $\textbf{Note:}$ The `dev` data set is meant to provide the **Project Feedback** and facilitate your implementation. For final evaluation, we will be using a totally different `test` data set.

# %% [markdown]
# $\textbf{TASK:}$
#
# Given a document $men\_doc = [w_1, w_2,...,w_Q]$; mention span within the document = $\{m_i\}$; and a collection of candidate entities for each mention alongwith corresponding entity description pages: $\{e_i\}_{i=1}^{n}$. You are required to use the:<br>
#
# 1. Mention
# * Mention's document (i.e., men_doc)
# * Entity description page for each candidate entity.
#
# to come up with a learning-to-rank model to rank the candidate entities corresponding to each mention in such a way that the Ground Truth Entity is ranked higher than the false candidates. **You are only allowed to:**
#
# * Use the $XGBoost$ classifier to build your learning-to-rank model.
#
#
# $\textbf{HINTS:}$
# 1. As a baseline model, you can use your experience gained in the Project (Part-1) to compute the TF-IDF statistics for words appearing in the mention and/or entity description pages. You can consider different ways to generate useful features for your learning-to-rank model. Your model should be able to achieve more than `70-%` accuracy for the `dev` set using basic TF-IDF features.
#
# * Later, you may think of advanced feaures to further enhance the performance of your model.
# * In order to train your XGBoost ranking classifier, you can start with the following parameters, and keep on improving them later:
# > * objective: `rank:pairwise`
#   * max_depth: `7-9`
#   * n_estimators: `4500-5500` <br>
#   * eta: `0.01-0.09`
#   * lambda: `~100`
#   * min_child_weight: `0.01-0.02`
#
# For XGBoost parameter description, see the following URL: https://xgboost.readthedocs.io/en/latest/parameter.html

# %% [markdown]
# ### NOTE
# 1. $\textbf{YOU SHOULD NOT HARD CODE}$ the Ground Truth in your implementation. Violations in this regard will get $\textbf{ZERO SCORE}$ for the $\textbf{Project (Part-1 + Part-2)}$.<br>
#
# * For final evaluation of $Q2$, we will be using different set of `test` data sets (with different numbers of testing mentions), which will follow the same format as that of the `dev` data.<br>
#
# * You model should not overfit the provided `dev` data set. Overfitting may lead to a worse performance for the `test` data sets and you may get a LOW SCORE.
#
# * For ranking entity candidates for each mention, you are $\textbf{NOT ALLOWED}$ to use Additional Information and/or External Resources other than the provided in the files corresponding to $Q2$.<br>
#
# * You are $\textbf{NOT ALLOWED}$ to use deep learning and/or pre-trained embedding models.
#
# * In order to come up with a learning-to-rank model, you are only allowed to use $XGBoost$ classifier (v0.90). You may check-out the documentation of the $XGBoost$ classifier via following url: https://xgboost.readthedocs.io/en/latest/python/python_api.html

# %% [markdown]
# ### Output Format (Q2):
#
# Your output should be a `dict()` of the form:<br>
#
# `{mid:'Entity_Label'}`, where <br>
# * `mid` corresponds to the mention id in the `dev` and/or `test` data set.
# * `Entity_Label` corresponds to the mention's most relevant entity label amongst the candidate labels.
#
# ### Running Time:
# * On CSE machine, your implementation should return the result within 10 minutes (600-sec) **(USER + SYSTEM)**.

# %% [markdown]
# ## How we test your implementation

# %%
## Import Necessary Modules...
import pickle
import project_part2 as project_part2

# %%
## Read the data sets...

### Read the Training Data
train_file = './Data/train.pickle'
train_mentions = pickle.load(open(train_file, 'rb'))

### Read the Training Labels...
train_label_file = './Data/train_labels.pickle'
train_labels = pickle.load(open(train_label_file, 'rb'))

### Read the Dev Data... (For Final Evaluation, we will replace it with the Test Data)
dev_file = './Data/dev.pickle'
dev_mentions = pickle.load(open(dev_file, 'rb'))

### Read the Parsed Entity Candidate Pages...
fname = './Data/parsed_candidate_entities.pickle'
parsed_entity_pages = pickle.load(open(fname, 'rb'))

### Read the Mention docs...
mens_docs_file = "./Data/men_docs.pickle"
men_docs = pickle.load(open(mens_docs_file, 'rb'))

# %% [markdown]
# ### 1. View men_docs

# %%
doc_name, doc_text = list(men_docs.items())[0]
print('doc_name: ', doc_name)
print('doc_text: ', doc_text)
# Out:
# doc_name:  24_Iraqi
# doc_text:  Iraqi captors of Sudanese jet charged with hijack.
#  LONDON 1996-08-30
#  Seven Iraqis who seized a Sudanese airliner with 199 people aboard and forced it to fly to London were on Friday charged with hijack, ending speculation that they might be offered immediate asylum in Britain.
#  Police said the seven men, who freed all their hostages after the plane landed at Stansted airport on Tuesday and then appealed for asylum, would appear in court on Saturday.
#  The Iraqis claimed they were " ordinary people persecuted by the regime of Saddam ( Hussein ) " but interior ministry officials had consistently said it was likely the seven would be charged with hijack before any plea for asylum was considered.
#  Under English law the maximum sentence for hijack is life imprisonment, but there has been widespread speculation that the seven will receive lesser sentences and then be allowed to stay rather than being sent back to Iraq.
#  The hijack began on Monday when an Amman-bound plane was taken over shortly after it took off from Khartoum.
#  The hijackers threatened to blow it up during a refuelling stop in Cyprus unless they were taken to London.
#  After a search of the aircraft following the hijackers ' surrender, police found only knives and fake explosives.

# %%
list(men_docs.keys())[:10]
# Out:
# ['24_Iraqi',
#  '10_SOCCER',
#  '55_Jeans',
#  '62_CYCLING',
#  '15_BOXING',
#  '4_SOCCER',
#  '66_SOCCER',
#  '40_Bonn',
#  '93_PRESS',
#  '63_CYCLING']

# %%
print(men_docs['98_Italy'])
# Out:
# Italy's Dini meets Burundi negotiator Nyerere.
#  ROME 1996-08-31
#  Italian Foreign Minister Lamberto Dini on Saturday met former Tanzanian president Julius Nyerere, the international negotiator for Burundi, the ministry said.
#  Nyerere arrived in Rome this week on a private visit and held talks with the U.S. special envoy to Burundi, Howard Wolpe, and the Sant ' Egidio Community, an Italian Roman Catholic organisation which has been monitoring Burundi closely.
#  " ( Nyerere ) informed Minister Dini of the latest developments in the ( Great Lakes ) region, with particular respect to Burundi following the military coup d'etat on July 25, " the ministry said in a statement.
#  It gave no details of their talks.
#  Nyerere was due to be presented with an " Artisans for Peace " prize by the Lay Volunteers ' International Organisation on Sunday.
#  He leaves Rome on Monday.
#  The U.N. Security Council on Friday condemned the coup by retired Tutsi major Pierre Buyoya and for the first time said in a resolution it intended to pressure Buyoya into unconditional negotiations with all parties and factions " without exception ".
#  Buyoya on Saturday dismissed its threat of an arms embargo against Burundi and flatly ruled out talks with Hutu rebels.
#  Some 150,000 people -- mostly civilians -- have died in Burundi since 1993 when the country's first democratically elected Hutu president was killed in an attempted army coup.

# %% [markdown]
# ### 2. View parsed_entity_pages

# %%
entity_name, descriptions = list(parsed_entity_pages.items())[0]
print('entity_name: ', entity_name)
print('descriptions: ')
print('(id, token, lemma, pos-tag, entity-tag)')
for d in descriptions[:5]:
    print(d)
# Out:
# entity_name:  Cartoon_Network_Nordic
# descriptions:
# (id, token, lemma, pos-tag, entity-tag)
# (1, 'Cartoon', 'Cartoon', 'PROPN', 'B-ORG')
# (2, 'Network', 'Network', 'PROPN', 'I-ORG')
# (3, 'television', 'television', 'NOUN', 'O')
# (4, 'channel', 'channel', 'NOUN', 'O')
# (5, 'broadcasting', 'broadcast', 'VERB', 'O')

# %%
i = 0
for entity_name, descriptions in parsed_entity_pages.items():
    if i > 3:
        break
    print('entity_name: ', entity_name)
    print('descriptions: ')
    print('(id, token, lemma, pos-tag, entity-tag)')
    for d in descriptions[:50]:
        print(d, len(descriptions))
    i += 1
# Out:
# entity_name:  Cartoon_Network_Nordic
# descriptions:
# (id, token, lemma, pos-tag, entity-tag)
# (1, 'Cartoon', 'Cartoon', 'PROPN', 'B-ORG') 389
# (2, 'Network', 'Network', 'PROPN', 'I-ORG') 389
# (3, 'television', 'television', 'NOUN', 'O') 389
# (4, 'channel', 'channel', 'NOUN', 'O') 389
# (5, 'broadcasting', 'broadcast', 'VERB', 'O') 389
# (6, 'youth', 'youth', 'NOUN', 'O') 389
# (7, 'children', 'child', 'NOUN', 'O') 389
# (8, 'programmes', 'programme', 'NOUN', 'O') 389
# (9, 'Sweden', 'Sweden', 'PROPN', 'B-GPE') 389
# (10, 'Norway', 'Norway', 'PROPN', 'B-GPE') 389
# (11, 'Denmark', 'Denmark', 'PROPN', 'B-GPE') 389
# (12, 'Finland', 'Finland', 'PROPN', 'B-GPE') 389
# (13, 'Iceland', 'Iceland', 'PROPN', 'B-GPE') 389
# (14, 'channel', 'channel', 'NOUN', 'O') 389
# (15, 'created', 'create', 'VERB', 'O') 389
# (16, '2000', '2000', 'NUM', 'O') 389
# (17, 'replaced', 'replace', 'VERB', 'O') 389
# (18, 'Pan', 'Pan', 'PROPN', 'O') 389
# (19, '-', '-', 'ADJ', 'O') 389
# (20, 'European', 'european', 'ADJ', 'O') 389
# (21, 'version', 'version', 'NOUN', 'O') 389
# (22, 'Cartoon', 'Cartoon', 'PROPN', 'B-ORG') 389
# (23, 'Network', 'Network', 'PROPN', 'I-ORG') 389
# (24, 'region', 'region', 'NOUN', 'O') 389
# (25, 'History', 'history', 'NOUN', 'O') 389
# (26, 'Cartoon', 'Cartoon', 'PROPN', 'O') 389
# (27, 'Network', 'Network', 'PROPN', 'O') 389
# (28, 'originally', 'originally', 'ADV', 'O') 389
# (29, 'twinned', 'twin', 'VERB', 'O') 389
# (30, 'movie', 'movie', 'NOUN', 'O') 389
# (31, 'channel', 'channel', 'NOUN', 'O') 389
# (32, 'TNT', 'TNT', 'PROPN', 'B-ORG') 389
# (33, 'pan', 'pan', 'ADJ', 'O') 389
# (34, '-', '-', 'ADJ', 'O') 389
# (35, 'European', 'european', 'ADJ', 'O') 389
# (36, 'version', 'version', 'NOUN', 'O') 389
# (37, 'Cartoon', 'Cartoon', 'PROPN', 'B-ORG') 389
# (38, 'Network', 'Network', 'PROPN', 'I-ORG') 389
# (39, 'ran', 'run', 'VERB', 'O') 389
# (40, '6:00am', '6:00am', 'NUM', 'O') 389
# (41, '8:00pm', '8:00pm', 'PROPN', 'O') 389
# (42, 'CET', 'CET', 'PROPN', 'O') 389
# (43, 'TNT', 'TNT', 'PROPN', 'B-ORG') 389
# (44, 'taking', 'take', 'VERB', 'O') 389
# (45, '8:00pm', '8:00pm', 'NUM', 'O') 389
# (46, '6:00am', '6:00am', 'PROPN', 'O') 389
# (47, 'CET', 'CET', 'PROPN', 'O') 389
# (48, 'programs', 'program', 'NOUN', 'O') 389
# (49, 'pan', 'pan', 'ADJ', 'O') 389
# (50, '-', '-', 'ADJ', 'O') 389
# entity_name:  Trial_of_Saddam_Hussein
# descriptions:
# (id, token, lemma, pos-tag, entity-tag)
# (1, 'Saddam', 'Saddam', 'PROPN', 'B-PERSON') 2368
# (2, 'Hussein', 'Hussein', 'PROPN', 'I-PERSON') 2368
# (3, 'sits', 'sit', 'VERB', 'O') 2368
# (4, 'Iraqi', 'iraqi', 'ADJ', 'O') 2368
# (5, 'judge', 'judge', 'NOUN', 'O') 2368
# (6, 'courthouse', 'courthouse', 'NOUN', 'O') 2368
# (7, 'Baghdad', 'Baghdad', 'PROPN', 'B-GPE') 2368
# (8, '1', '1', 'NUM', 'O') 2368
# (9, 'July', 'July', 'PROPN', 'O') 2368
# (10, '2004', '2004', 'NUM', 'O') 2368
# (11, 'Trial', 'Trial', 'PROPN', 'O') 2368
# (12, 'Saddam', 'Saddam', 'PROPN', 'B-PERSON') 2368
# (13, 'Hussein', 'Hussein', 'PROPN', 'I-PERSON') 2368
# (14, 'trial', 'trial', 'NOUN', 'O') 2368
# (15, 'deposed', 'deposed', 'ADJ', 'O') 2368
# (16, 'President', 'President', 'PROPN', 'O') 2368
# (17, 'Iraq', 'Iraq', 'PROPN', 'B-GPE') 2368
# (18, 'Saddam', 'Saddam', 'PROPN', 'B-PERSON') 2368
# (19, 'Hussein', 'Hussein', 'PROPN', 'I-PERSON') 2368
# (20, 'the', 'the', 'DET', 'B-ORG') 2368
# (21, 'Iraqi', 'iraqi', 'ADJ', 'I-ORG') 2368
# (22, 'Interim', 'interim', 'ADJ', 'I-ORG') 2368
# (23, 'Government', 'Government', 'PROPN', 'I-ORG') 2368
# (24, 'crimes', 'crime', 'NOUN', 'O') 2368
# (25, 'humanity', 'humanity', 'NOUN', 'O') 2368
# (26, 'time', 'time', 'NOUN', 'O') 2368
# (27, 'office', 'office', 'NOUN', 'O') 2368
# (28, 'The', 'the', 'DET', 'B-ORG') 2368
# (29, 'Coalition', 'Coalition', 'PROPN', 'I-ORG') 2368
# (30, 'Provisional', 'Provisional', 'PROPN', 'I-ORG') 2368
# (31, 'Authority', 'Authority', 'PROPN', 'I-ORG') 2368
# (32, 'voted', 'vote', 'VERB', 'O') 2368
# (33, 'create', 'create', 'VERB', 'O') 2368
# (34, 'the', 'the', 'DET', 'B-ORG') 2368
# (35, 'Iraqi', 'Iraqi', 'PROPN', 'I-ORG') 2368
# (36, 'Special', 'Special', 'PROPN', 'I-ORG') 2368
# (37, 'Tribunal', 'Tribunal', 'PROPN', 'I-ORG') 2368
# (38, 'IST', 'IST', 'PROPN', 'O') 2368
# (39, 'consisting', 'consist', 'VERB', 'O') 2368
# (40, 'five', 'five', 'NUM', 'O') 2368
# (41, 'Iraqi', 'iraqi', 'ADJ', 'O') 2368
# (42, 'judges', 'judge', 'NOUN', 'O') 2368
# (43, '9', '9', 'NUM', 'O') 2368
# (44, 'December', 'December', 'PROPN', 'O') 2368
# (45, '2003', '2003', 'NUM', 'O') 2368
# (46, 'try', 'try', 'VERB', 'O') 2368
# (47, 'Saddam', 'Saddam', 'PROPN', 'B-PERSON') 2368
# (48, 'Hussein', 'Hussein', 'PROPN', 'I-PERSON') 2368
# (49, 'aides', 'aide', 'NOUN', 'O') 2368
# (50, 'charges', 'charge', 'NOUN', 'O') 2368
# entity_name:  Fritz_Henke
# descriptions:
# (id, token, lemma, pos-tag, entity-tag)
# (1, 'Fritz', 'Fritz', 'PROPN', 'B-PERSON') 146
# (2, 'Henke', 'Henke', 'PROPN', 'I-PERSON') 146
# (3, '21', '21', 'NUM', 'O') 146
# (4, 'June', 'June', 'PROPN', 'O') 146
# (5, '1921', '1921', 'NUM', 'O') 146
# (6, '15', '15', 'NUM', 'O') 146
# (7, 'November', 'November', 'PROPN', 'O') 146
# (8, '1999', '1999', 'NUM', 'O') 146
# (9, 'Untersturmführer', 'Untersturmführer', 'PROPN', 'O') 146
# (10, 'Second', 'Second', 'PROPN', 'O') 146
# (11, 'Lieutenant', 'Lieutenant', 'PROPN', 'O') 146
# (12, 'the', 'the', 'DET', 'B-ORG') 146
# (13, 'Waffen', 'Waffen', 'PROPN', 'I-ORG') 146
# (14, 'SS', 'SS', 'PROPN', 'I-ORG') 146
# (15, 'awarded', 'award', 'VERB', 'O') 146
# (16, 'Knight', 'Knight', 'PROPN', 'O') 146
# (17, 'Cross', 'Cross', 'PROPN', 'B-ORG') 146
# (18, 'of', 'of', 'ADP', 'I-ORG') 146
# (19, 'the', 'the', 'DET', 'I-ORG') 146
# (20, 'Iron', 'Iron', 'PROPN', 'I-ORG') 146
# (21, 'Cross', 'Cross', 'PROPN', 'I-ORG') 146
# (22, 'Henke', 'Henke', 'PROPN', 'O') 146
# (23, 'born', 'bear', 'VERB', 'O') 146
# (24, 'the', 'the', 'DET', 'O') 146
# (25, '21', '21', 'NUM', 'O') 146
# (26, 'June', 'June', 'PROPN', 'O') 146
# (27, '1921', '1921', 'NUM', 'O') 146
# (28, 'Oldendorf', 'Oldendorf', 'PROPN', 'B-GPE') 146
# (29, 'Lower', 'Lower', 'PROPN', 'B-ORG') 146
# (30, 'Saxony', 'Saxony', 'PROPN', 'I-ORG') 146
# (31, 'school', 'school', 'NOUN', 'O') 146
# (32, 'planned', 'plan', 'VERB', 'O') 146
# (33, 'Master', 'Master', 'PROPN', 'O') 146
# (34, 'craftsman', 'craftsman', 'NOUN', 'O') 146
# (35, 'the', 'the', 'DET', 'O') 146
# (36, '4', '4', 'NUM', 'O') 146
# (37, 'September', 'September', 'PROPN', 'O') 146
# (38, '1939', '1939', 'NUM', 'O') 146
# (39, 'volunteered', 'volunteer', 'VERB', 'O') 146
# (40, 'join', 'join', 'VERB', 'O') 146
# (41, 'SS', 'ss', 'NOUN', 'B-ORG') 146
# (42, 'posted', 'post', 'VERB', 'O') 146
# (43, 'the', 'the', 'DET', 'B-ORG') 146
# (44, '2nd', '2nd', 'PROPN', 'I-ORG') 146
# (45, 'Reserve', 'Reserve', 'PROPN', 'I-ORG') 146
# (46, 'Company', 'Company', 'PROPN', 'I-ORG') 146
# (47, 'the', 'the', 'DET', 'B-ORG') 146
# (48, 'SS', 'SS', 'PROPN', 'I-ORG') 146
# (49, 'Regiment', 'Regiment', 'PROPN', 'I-ORG') 146
# (50, '"', '"', 'PUNCT', 'I-ORG') 146
# entity_name:  IranIraq_War
# descriptions:
# (id, token, lemma, pos-tag, entity-tag)
# (1, 'Iran', 'Iran', 'PROPN', 'B-GPE') 5002
# (2, 'Iraq', 'Iraq', 'PROPN', 'O') 5002
# (3, 'War', 'War', 'PROPN', 'O') 5002
# (4, 'known', 'know', 'VERB', 'O') 5002
# (5, 'the', 'the', 'DET', 'O') 5002
# (6, 'First', 'First', 'PROPN', 'O') 5002
# (7, 'Persian', 'Persian', 'PROPN', 'O') 5002
# (8, 'Gulf', 'Gulf', 'PROPN', 'O') 5002
# (9, 'War', 'War', 'PROPN', 'O') 5002
# (10, 'armed', 'armed', 'ADJ', 'O') 5002
# (11, 'conflict', 'conflict', 'NOUN', 'O') 5002
# (12, 'Islamic', 'Islamic', 'PROPN', 'O') 5002
# (13, 'Republic', 'Republic', 'PROPN', 'O') 5002
# (14, 'Iran', 'Iran', 'PROPN', 'O') 5002
# (15, 'the', 'the', 'DET', 'B-GPE') 5002
# (16, "Ba'athist", "Ba'athist", 'PROPN', 'I-GPE') 5002
# (17, 'Republic', 'Republic', 'PROPN', 'I-GPE') 5002
# (18, 'of', 'of', 'ADP', 'I-GPE') 5002
# (19, 'Iraq', 'Iraq', 'PROPN', 'I-GPE') 5002
# (20, 'lasting', 'last', 'VERB', 'O') 5002
# (21, 'September', 'September', 'PROPN', 'O') 5002
# (22, '1980', '1980', 'NUM', 'O') 5002
# (23, 'to', 'to', 'ADP', 'O') 5002
# (24, 'August', 'August', 'PROPN', 'O') 5002
# (25, '1988', '1988', 'NUM', 'O') 5002
# (26, 'making', 'make', 'VERB', 'O') 5002
# (27, 'the', 'the', 'DET', 'O') 5002
# (28, '20th', '20th', 'ADJ', 'O') 5002
# (29, 'century', 'century', 'NOUN', 'O') 5002
# (30, "'s", "'s", 'PART', 'O') 5002
# (31, 'longest', 'long', 'ADJ', 'O') 5002
# (32, 'conventional', 'conventional', 'ADJ', 'O') 5002
# (33, 'war', 'war', 'NOUN', 'O') 5002
# (34, 'initially', 'initially', 'ADV', 'O') 5002
# (35, 'referred', 'refer', 'VERB', 'O') 5002
# (36, 'English', 'English', 'PROPN', 'O') 5002
# (37, 'the', 'the', 'DET', 'O') 5002
# (38, '"', '"', 'PUNCT', 'O') 5002
# (39, 'Gulf', 'Gulf', 'PROPN', 'O') 5002
# (40, 'War', 'War', 'PROPN', 'O') 5002
# (41, 'prior', 'prior', 'ADV', 'O') 5002
# (42, 'the', 'the', 'DET', 'O') 5002
# (43, 'Persian', 'Persian', 'PROPN', 'O') 5002
# (44, 'Gulf', 'Gulf', 'PROPN', 'O') 5002
# (45, 'War', 'War', 'PROPN', 'O') 5002
# (46, 'the', 'the', 'DET', 'O') 5002
# (47, 'early', 'early', 'ADJ', 'O') 5002
# (48, '1990s', '1990', 'NOUN', 'O') 5002
# (49, 'The', 'the', 'DET', 'O') 5002
# (50, 'Iran', 'Iran', 'PROPN', 'O') 5002

# %% [markdown]
# ### 3. View train_mentions

# %%
print('(mention_id, )')
list(train_mentions.items())[1]
# Out:
# (mention_id, )
# (2,
#  {'doc_title': '1_GOLF',
#   'mention': 'World Series of Golf',
#   'offset': 2097,
#   'length': 20,
#   'candidate_entities': ['World_Series_of_Golf',
#    'WGC-Bridgestone_Invitational']})

# %%
i = 0
for key, value in train_mentions.items():
    if i > 3:
        break
    for entity in value['candidate_entities']:
        print(entity)
    i += 1
# Out:
# Professional_Golfers_Association
# PGA_Tour
# Golf_Channel_on_NBC
# 2009_PGA_Tour
# 2011_PGA_Tour
# 2008_PGA_Tour
# PGA_Tour_on_CBS
# World_Series_of_Golf
# WGC-Bridgestone_Invitational
# Cuba_Merced_County_California
# History_of_Cuba
# Cuba_North_Dakota
# Cuba
# Cuba_Indiana
# Cuba_at_the_2011_World_Aquatics_Championships
# Football_Association_of_Cuba
# ChinaCuba_relations
# Slovenia
# Economy_of_Slovenia
# Slovenia_at_the_Paralympics
# Slovenian_Parliament
# Slovenia_at_the_2009_Mediterranean_Games
# Slovenia_mens_national_ice_hockey_team
# Recognition_of_same-sex_unions_in_Slovenia

# %% [markdown]
# ### 4. View train_labels

# %%
i = 0
for key, value in train_labels.items():
    if i > 10:
        break
    print(value['mention'])
    i += 1
# Out:
# PGA Tour
# World Series of Golf
# Cuba
# Slovenia
# Jamaica
# Switzerland
# Jamaica
# Russia
# France
# Portugal
# Russia

# %%
list(train_mentions.items())[940]
# Out:
# (941,
#  {'doc_title': '98_Italy',
#   'mention': 'U.S.',
#   'offset': 302,
#   'length': 4,
#   'candidate_entities': ['United_States_Davis_Cup_team',
#    'Rock__Rule',
#    'US_National_Badminton_Championships',
#    'Militia_United_States',
#    'United_States',
#    'AP_United_States_History',
#    'United_States_Postal_Service',
#    'United_States_at_the_1988_Summer_Olympics']})

# %%
i = 0
for key, value in train_labels.items():
    #if i > 30:
    #    break
    
    if value['mention'].split() != value['label'].split('_'):
        print(value['mention'], value['label'])
        print(key, value)
    i += 1
# Out:
# U.S. United_States
# 15 {'doc_title': '2_ATHLETICS', 'mention': 'U.S.', 'label': 'United_States'}
# U.S. United_States
# 16 {'doc_title': '2_ATHLETICS', 'mention': 'U.S.', 'label': 'United_States'}
# Britain United_Kingdom
# 17 {'doc_title': '2_ATHLETICS', 'mention': 'Britain', 'label': 'United_Kingdom'}
# U.S. United_States
# 21 {'doc_title': '2_ATHLETICS', 'mention': 'U.S.', 'label': 'United_States'}
# U.S. United_States
# 23 {'doc_title': '2_ATHLETICS', 'mention': 'U.S.', 'label': 'United_States'}
# U.S. United_States
# 25 {'doc_title': '2_ATHLETICS', 'mention': 'U.S.', 'label': 'United_States'}
# U.S. United_States
# 32 {'doc_title': '2_ATHLETICS', 'mention': 'U.S.', 'label': 'United_States'}
# Britain United_Kingdom
# 47 {'doc_title': '2_ATHLETICS', 'mention': 'Britain', 'label': 'United_Kingdom'}
# Ireland Republic_of_Ireland
# 48 {'doc_title': '2_ATHLETICS', 'mention': 'Ireland', 'label': 'Republic_of_Ireland'}
# U.S. United_States
# 51 {'doc_title': '2_ATHLETICS', 'mention': 'U.S.', 'label': 'United_States'}
# U.S. United_States
# 58 {'doc_title': '2_ATHLETICS', 'mention': 'U.S.', 'label': 'United_States'}
# U.S. United_States
# 60 {'doc_title': '2_ATHLETICS', 'mention': 'U.S.', 'label': 'United_States'}
# U.S. United_States
# 62 {'doc_title': '2_ATHLETICS', 'mention': 'U.S.', 'label': 'United_States'}
# Bahamas The_Bahamas
# 63 {'doc_title': '2_ATHLETICS', 'mention': 'Bahamas', 'label': 'The_Bahamas'}
# U.S. United_States
# 65 {'doc_title': '2_ATHLETICS', 'mention': 'U.S.', 'label': 'United_States'}
# U.S. United_States
# 74 {'doc_title': '2_ATHLETICS', 'mention': 'U.S.', 'label': 'United_States'}
# U.S. United_States
# 76 {'doc_title': '2_ATHLETICS', 'mention': 'U.S.', 'label': 'United_States'}
# U.S. United_States
# 79 {'doc_title': '2_ATHLETICS', 'mention': 'U.S.', 'label': 'United_States'}
# U.S. United_States
# 83 {'doc_title': '2_ATHLETICS', 'mention': 'U.S.', 'label': 'United_States'}
# Britain United_Kingdom
# 87 {'doc_title': '2_ATHLETICS', 'mention': 'Britain', 'label': 'United_Kingdom'}
# U.S. United_States
# 91 {'doc_title': '2_ATHLETICS', 'mention': 'U.S.', 'label': 'United_States'}
# U.S. United_States
# 95 {'doc_title': '2_ATHLETICS', 'mention': 'U.S.', 'label': 'United_States'}
# Britain United_Kingdom
# 107 {'doc_title': '2_ATHLETICS', 'mention': 'Britain', 'label': 'United_Kingdom'}
# U.S. United_States
# 126 {'doc_title': '2_ATHLETICS', 'mention': 'U.S.', 'label': 'United_States'}
# Britain United_Kingdom
# 134 {'doc_title': '2_ATHLETICS', 'mention': 'Britain', 'label': 'United_Kingdom'}
# U.S. United_States
# 137 {'doc_title': '2_ATHLETICS', 'mention': 'U.S.', 'label': 'United_States'}
# U.S. United_States
# 138 {'doc_title': '2_ATHLETICS', 'mention': 'U.S.', 'label': 'United_States'}
# U.S. United_States
# 153 {'doc_title': '2_ATHLETICS', 'mention': 'U.S.', 'label': 'United_States'}
# Britain United_Kingdom
# 155 {'doc_title': '2_ATHLETICS', 'mention': 'Britain', 'label': 'United_Kingdom'}
# DUBLIN Dublin
# 164 {'doc_title': '6_BOXING', 'mention': 'DUBLIN', 'label': 'Dublin'}
# American United_States
# 165 {'doc_title': '6_BOXING', 'mention': 'American', 'label': 'United_States'}
# Guingamp En_Avant_de_Guingamp
# 166 {'doc_title': '7_SOCCER', 'mention': 'Guingamp', 'label': 'En_Avant_de_Guingamp'}
# Nice OGC_Nice
# 167 {'doc_title': '7_SOCCER', 'mention': 'Nice', 'label': 'OGC_Nice'}
# ENGLISH COUNTY CHAMPIONSHIP County_Championship
# 168 {'doc_title': '9_CRICKET', 'mention': 'ENGLISH COUNTY CHAMPIONSHIP', 'label': 'County_Championship'}
# LITHUANIA Lithuania_national_football_team
# 169 {'doc_title': '10_SOCCER', 'mention': 'LITHUANIA', 'label': 'Lithuania_national_football_team'}
# BUCHAREST Bucharest
# 170 {'doc_title': '10_SOCCER', 'mention': 'BUCHAREST', 'label': 'Bucharest'}
# European Europe
# 171 {'doc_title': '10_SOCCER', 'mention': 'European', 'label': 'Europe'}
# LONDON London
# 172 {'doc_title': '9_CRICKET', 'mention': 'LONDON', 'label': 'London'}
# English England
# 173 {'doc_title': '9_CRICKET', 'mention': 'English', 'label': 'England'}
# Leicestershire Leicestershire_County_Cricket_Club
# 175 {'doc_title': '9_CRICKET', 'mention': 'Leicestershire', 'label': 'Leicestershire_County_Cricket_Club'}
# Leicestershire Leicestershire_County_Cricket_Club
# 176 {'doc_title': '9_CRICKET', 'mention': 'Leicestershire', 'label': 'Leicestershire_County_Cricket_Club'}
# Leicestershire Leicestershire_County_Cricket_Club
# 177 {'doc_title': '9_CRICKET', 'mention': 'Leicestershire', 'label': 'Leicestershire_County_Cricket_Club'}
# Glamorgan Glamorgan_County_Cricket_Club
# 178 {'doc_title': '9_CRICKET', 'mention': 'Glamorgan', 'label': 'Glamorgan_County_Cricket_Club'}
# Durham Durham_County_Cricket_Club
# 179 {'doc_title': '9_CRICKET', 'mention': 'Durham', 'label': 'Durham_County_Cricket_Club'}
# Tunbridge Wells Royal_Tunbridge_Wells
# 180 {'doc_title': '9_CRICKET', 'mention': 'Tunbridge Wells', 'label': 'Royal_Tunbridge_Wells'}
# Nottinghamshire Nottinghamshire_County_Cricket_Club
# 181 {'doc_title': '9_CRICKET', 'mention': 'Nottinghamshire', 'label': 'Nottinghamshire_County_Cricket_Club'}
# Kent Kent_County_Cricket_Club
# 182 {'doc_title': '9_CRICKET', 'mention': 'Kent', 'label': 'Kent_County_Cricket_Club'}
# Warwickshire Warwickshire_County_Cricket_Club
# 185 {'doc_title': '9_CRICKET', 'mention': 'Warwickshire', 'label': 'Warwickshire_County_Cricket_Club'}
# Surrey Surrey_County_Cricket_Club
# 186 {'doc_title': '9_CRICKET', 'mention': 'Surrey', 'label': 'Surrey_County_Cricket_Club'}
# Sussex Sussex_County_Cricket_Club
# 188 {'doc_title': '9_CRICKET', 'mention': 'Sussex', 'label': 'Sussex_County_Cricket_Club'}
# Middlesex Middlesex_County_Cricket_Club
# 189 {'doc_title': '9_CRICKET', 'mention': 'Middlesex', 'label': 'Middlesex_County_Cricket_Club'}
# Hampshire Hampshire_County_Cricket_Club
# 190 {'doc_title': '9_CRICKET', 'mention': 'Hampshire', 'label': 'Hampshire_County_Cricket_Club'}
# Worcestershire Worcestershire_County_Cricket_Club
# 192 {'doc_title': '9_CRICKET', 'mention': 'Worcestershire', 'label': 'Worcestershire_County_Cricket_Club'}
# Derbyshire Derbyshire_County_Cricket_Club
# 193 {'doc_title': '9_CRICKET', 'mention': 'Derbyshire', 'label': 'Derbyshire_County_Cricket_Club'}
# Gloucestershire Gloucestershire_County_Cricket_Club
# 195 {'doc_title': '9_CRICKET', 'mention': 'Gloucestershire', 'label': 'Gloucestershire_County_Cricket_Club'}
# Northamptonshire Northamptonshire_County_Cricket_Club
# 196 {'doc_title': '9_CRICKET', 'mention': 'Northamptonshire', 'label': 'Northamptonshire_County_Cricket_Club'}
# SWEDEN Sweden_national_football_team
# 197 {'doc_title': '12_SOCCER', 'mention': 'SWEDEN', 'label': 'Sweden_national_football_team'}
# LATVIA Latvia_national_football_team
# 198 {'doc_title': '12_SOCCER', 'mention': 'LATVIA', 'label': 'Latvia_national_football_team'}
# EUROPEAN Europe
# 199 {'doc_title': '12_SOCCER', 'mention': 'EUROPEAN', 'label': 'Europe'}
# SHEARER Alan_Shearer
# 200 {'doc_title': '13_SOCCER', 'mention': 'SHEARER', 'label': 'Alan_Shearer'}
# ENGLAND England_national_football_team
# 201 {'doc_title': '13_SOCCER', 'mention': 'ENGLAND', 'label': 'England_national_football_team'}
# LONDON London
# 202 {'doc_title': '13_SOCCER', 'mention': 'LONDON', 'label': 'London'}
# England England_national_football_team
# 203 {'doc_title': '13_SOCCER', 'mention': 'England', 'label': 'England_national_football_team'}
# European Europe
# 204 {'doc_title': '13_SOCCER', 'mention': 'European', 'label': 'Europe'}
# England England_national_football_team
# 205 {'doc_title': '13_SOCCER', 'mention': 'England', 'label': 'England_national_football_team'}
# World Cup 1998_FIFA_World_Cup
# 206 {'doc_title': '13_SOCCER', 'mention': 'World Cup', 'label': '1998_FIFA_World_Cup'}
# Moldova Moldova_national_football_team
# 207 {'doc_title': '13_SOCCER', 'mention': 'Moldova', 'label': 'Moldova_national_football_team'}
# Shearer Alan_Shearer
# 208 {'doc_title': '13_SOCCER', 'mention': 'Shearer', 'label': 'Alan_Shearer'}
# Alan Alan_Shearer
# 209 {'doc_title': '13_SOCCER', 'mention': 'Alan', 'label': 'Alan_Shearer'}
# Hoddle Glenn_Hoddle
# 210 {'doc_title': '13_SOCCER', 'mention': 'Hoddle', 'label': 'Glenn_Hoddle'}
# Alan Alan_Shearer
# 211 {'doc_title': '13_SOCCER', 'mention': 'Alan', 'label': 'Alan_Shearer'}
# Shearer Alan_Shearer
# 212 {'doc_title': '13_SOCCER', 'mention': 'Shearer', 'label': 'Alan_Shearer'}
# Euro 96 UEFA_Euro_1996
# 213 {'doc_title': '13_SOCCER', 'mention': 'Euro 96', 'label': 'UEFA_Euro_1996'}
# Shearer Alan_Shearer
# 214 {'doc_title': '13_SOCCER', 'mention': 'Shearer', 'label': 'Alan_Shearer'}
# BELGRADE Belgrade
# 215 {'doc_title': '14_BASKETBALL', 'mention': 'BELGRADE', 'label': 'Belgrade'}
# Red Star KK_Crvena_zvezda
# 216 {'doc_title': '14_BASKETBALL', 'mention': 'Red Star', 'label': 'KK_Crvena_zvezda'}
# ROMANIA Romania_national_football_team
# 219 {'doc_title': '10_SOCCER', 'mention': 'ROMANIA', 'label': 'Romania_national_football_team'}
# PANAMA Panama
# 220 {'doc_title': '15_BOXING', 'mention': 'PANAMA', 'label': 'Panama'}
# PANAMA CITY Panama_City
# 221 {'doc_title': '15_BOXING', 'mention': 'PANAMA CITY', 'label': 'Panama_City'}
# Panamanian Panama
# 222 {'doc_title': '15_BOXING', 'mention': 'Panamanian', 'label': 'Panama'}
# Mexican Mexico
# 223 {'doc_title': '15_BOXING', 'mention': 'Mexican', 'label': 'Mexico'}
# RIGA Riga
# 225 {'doc_title': '12_SOCCER', 'mention': 'RIGA', 'label': 'Riga'}
# Panamanian Panama
# 227 {'doc_title': '15_BOXING', 'mention': 'Panamanian', 'label': 'Panama'}
# Panamanian Panama
# 230 {'doc_title': '15_BOXING', 'mention': 'Panamanian', 'label': 'Panama'}
# Sweden Sweden_national_football_team
# 231 {'doc_title': '12_SOCCER', 'mention': 'Sweden', 'label': 'Sweden_national_football_team'}
# Latvia Latvia_national_football_team
# 232 {'doc_title': '12_SOCCER', 'mention': 'Latvia', 'label': 'Latvia_national_football_team'}
# NFL National_Football_League
# 233 {'doc_title': '16_NFL', 'mention': 'NFL', 'label': 'National_Football_League'}
# CUNNINGHAM Randall_Cunningham
# 234 {'doc_title': '16_NFL', 'mention': 'CUNNINGHAM', 'label': 'Randall_Cunningham'}
# PHILADELPHIA Philadelphia
# 235 {'doc_title': '16_NFL', 'mention': 'PHILADELPHIA', 'label': 'Philadelphia'}
# Cunningham Randall_Cunningham
# 238 {'doc_title': '16_NFL', 'mention': 'Cunningham', 'label': 'Randall_Cunningham'}
# Cunningham Randall_Cunningham
# 241 {'doc_title': '16_NFL', 'mention': 'Cunningham', 'label': 'Randall_Cunningham'}
# Eagles Philadelphia_Eagles
# 242 {'doc_title': '16_NFL', 'mention': 'Eagles', 'label': 'Philadelphia_Eagles'}
# CALIFORNIA Los_Angeles_Angels_of_Anaheim
# 244 {'doc_title': '17_BASEBALL', 'mention': 'CALIFORNIA', 'label': 'Los_Angeles_Angels_of_Anaheim'}
# New York New_York_Yankees
# 245 {'doc_title': '17_BASEBALL', 'mention': 'New York', 'label': 'New_York_Yankees'}
# European Europe
# 246 {'doc_title': '12_SOCCER', 'mention': 'European', 'label': 'Europe'}
# SEATTLE Seattle_Mariners
# 247 {'doc_title': '17_BASEBALL', 'mention': 'SEATTLE', 'label': 'Seattle_Mariners'}
# Baltimore Baltimore_Orioles
# 248 {'doc_title': '17_BASEBALL', 'mention': 'Baltimore', 'label': 'Baltimore_Orioles'}
# NEW YORK New_York_City
# 251 {'doc_title': '17_BASEBALL', 'mention': 'NEW YORK', 'label': 'New_York_City'}
# Chicago Chicago_White_Sox
# 252 {'doc_title': '17_BASEBALL', 'mention': 'Chicago', 'label': 'Chicago_White_Sox'}
# Cincinnati Cincinnati_Reds
# 253 {'doc_title': '17_BASEBALL', 'mention': 'Cincinnati', 'label': 'Cincinnati_Reds'}
# COLORADO Colorado_Rockies
# 254 {'doc_title': '17_BASEBALL', 'mention': 'COLORADO', 'label': 'Colorado_Rockies'}
# Atlanta Atlanta_Braves
# 255 {'doc_title': '17_BASEBALL', 'mention': 'Atlanta', 'label': 'Atlanta_Braves'}
# PITTSBURGH Pittsburgh_Pirates
# 256 {'doc_title': '17_BASEBALL', 'mention': 'PITTSBURGH', 'label': 'Pittsburgh_Pirates'}
# Los Angeles Los_Angeles_Dodgers
# 257 {'doc_title': '17_BASEBALL', 'mention': 'Los Angeles', 'label': 'Los_Angeles_Dodgers'}
# MONTREAL Montreal
# 258 {'doc_title': '17_BASEBALL', 'mention': 'MONTREAL', 'label': 'Montreal'}
# MAJOR LEAGUE Major_League_Baseball
# 259 {'doc_title': '17_BASEBALL', 'mention': 'MAJOR LEAGUE', 'label': 'Major_League_Baseball'}
# NEW YORK New_York_City
# 260 {'doc_title': '17_BASEBALL', 'mention': 'NEW YORK', 'label': 'New_York_City'}
# Major League Major_League_Baseball
# 261 {'doc_title': '17_BASEBALL', 'mention': 'Major League', 'label': 'Major_League_Baseball'}
# DETROIT Detroit_Tigers
# 263 {'doc_title': '17_BASEBALL', 'mention': 'DETROIT', 'label': 'Detroit_Tigers'}
# Kansas City Kansas_City_Royals
# 264 {'doc_title': '17_BASEBALL', 'mention': 'Kansas City', 'label': 'Kansas_City_Royals'}
# Minnesota Minnesota_Twins
# 265 {'doc_title': '17_BASEBALL', 'mention': 'Minnesota', 'label': 'Minnesota_Twins'}
# MILWAUKEE Milwaukee_Brewers
# 266 {'doc_title': '17_BASEBALL', 'mention': 'MILWAUKEE', 'label': 'Milwaukee_Brewers'}
# Cunningham Randall_Cunningham
# 267 {'doc_title': '16_NFL', 'mention': 'Cunningham', 'label': 'Randall_Cunningham'}
# Randall Randall_Cunningham
# 268 {'doc_title': '16_NFL', 'mention': 'Randall', 'label': 'Randall_Cunningham'}
# NFL National_Football_League
# 269 {'doc_title': '16_NFL', 'mention': 'NFL', 'label': 'National_Football_League'}
# Eagles Philadelphia_Eagles
# 270 {'doc_title': '16_NFL', 'mention': 'Eagles', 'label': 'Philadelphia_Eagles'}
# Randall Randall_Cunningham
# 272 {'doc_title': '16_NFL', 'mention': 'Randall', 'label': 'Randall_Cunningham'}
# Eagles Philadelphia_Eagles
# 273 {'doc_title': '16_NFL', 'mention': 'Eagles', 'label': 'Philadelphia_Eagles'}
# NFL National_Football_League
# 275 {'doc_title': '16_NFL', 'mention': 'NFL', 'label': 'National_Football_League'}
# Cunningham Randall_Cunningham
# 276 {'doc_title': '16_NFL', 'mention': 'Cunningham', 'label': 'Randall_Cunningham'}
# Cunningham Randall_Cunningham
# 277 {'doc_title': '16_NFL', 'mention': 'Cunningham', 'label': 'Randall_Cunningham'}
# HENKE Nolan_Henke
# 280 {'doc_title': '1_GOLF', 'mention': 'HENKE', 'label': 'Nolan_Henke'}
# MILWAUKEE Milwaukee
# 281 {'doc_title': '1_GOLF', 'mention': 'MILWAUKEE', 'label': 'Milwaukee'}
# WOODS Tiger_Woods
# 282 {'doc_title': '1_GOLF', 'mention': 'WOODS', 'label': 'Tiger_Woods'}
# MILWAUKEE Milwaukee
# 283 {'doc_title': '1_GOLF', 'mention': 'MILWAUKEE', 'label': 'Milwaukee'}
# Henke Nolan_Henke
# 286 {'doc_title': '1_GOLF', 'mention': 'Henke', 'label': 'Nolan_Henke'}
# Woods Tiger_Woods
# 287 {'doc_title': '1_GOLF', 'mention': 'Woods', 'label': 'Tiger_Woods'}
# Woods Tiger_Woods
# 288 {'doc_title': '1_GOLF', 'mention': 'Woods', 'label': 'Tiger_Woods'}
# Henke Nolan_Henke
# 289 {'doc_title': '1_GOLF', 'mention': 'Henke', 'label': 'Nolan_Henke'}
# Henke Nolan_Henke
# 290 {'doc_title': '1_GOLF', 'mention': 'Henke', 'label': 'Nolan_Henke'}
# Estes Bob_Estes
# 292 {'doc_title': '1_GOLF', 'mention': 'Estes', 'label': 'Bob_Estes'}
# Texas Open Valero_Texas_Open
# 293 {'doc_title': '1_GOLF', 'mention': 'Texas Open', 'label': 'Valero_Texas_Open'}
# Woods Tiger_Woods
# 294 {'doc_title': '1_GOLF', 'mention': 'Woods', 'label': 'Tiger_Woods'}
# MITCHELL Dennis_Mitchell
# 295 {'doc_title': '18_ATHLETICS', 'mention': 'MITCHELL', 'label': 'Dennis_Mitchell'}
# BAILEY Donovan_Bailey
# 296 {'doc_title': '18_ATHLETICS', 'mention': 'BAILEY', 'label': 'Donovan_Bailey'}
# AUSTRALIA Australia_national_cricket_team
# 297 {'doc_title': '19_CRICKET', 'mention': 'AUSTRALIA', 'label': 'Australia_national_cricket_team'}
# BERLIN Berlin
# 298 {'doc_title': '18_ATHLETICS', 'mention': 'BERLIN', 'label': 'Berlin'}
# American United_States
# 299 {'doc_title': '18_ATHLETICS', 'mention': 'American', 'label': 'United_States'}
# Olympic Olympic_sports
# 301 {'doc_title': '18_ATHLETICS', 'mention': 'Olympic', 'label': 'Olympic_sports'}
# Olympic Olympic_sports
# 302 {'doc_title': '18_ATHLETICS', 'mention': 'Olympic', 'label': 'Olympic_sports'}
# Mitchell Dennis_Mitchell
# 304 {'doc_title': '18_ATHLETICS', 'mention': 'Mitchell', 'label': 'Dennis_Mitchell'}
# Bailey Donovan_Bailey
# 305 {'doc_title': '18_ATHLETICS', 'mention': 'Bailey', 'label': 'Donovan_Bailey'}
# Bailey Donovan_Bailey
# 306 {'doc_title': '18_ATHLETICS', 'mention': 'Bailey', 'label': 'Donovan_Bailey'}
# American United_States
# 308 {'doc_title': '18_ATHLETICS', 'mention': 'American', 'label': 'United_States'}
# Bailey Donovan_Bailey
# 310 {'doc_title': '18_ATHLETICS', 'mention': 'Bailey', 'label': 'Donovan_Bailey'}
# Mitchell Dennis_Mitchell
# 311 {'doc_title': '18_ATHLETICS', 'mention': 'Mitchell', 'label': 'Dennis_Mitchell'}
# Atlanta Games 1996_Summer_Olympics
# 312 {'doc_title': '18_ATHLETICS', 'mention': 'Atlanta Games', 'label': '1996_Summer_Olympics'}
# Olympic Olympic_sports
# 313 {'doc_title': '18_ATHLETICS', 'mention': 'Olympic', 'label': 'Olympic_sports'}
# Bailey Donovan_Bailey
# 314 {'doc_title': '18_ATHLETICS', 'mention': 'Bailey', 'label': 'Donovan_Bailey'}
# Bailey Donovan_Bailey
# 316 {'doc_title': '18_ATHLETICS', 'mention': 'Bailey', 'label': 'Donovan_Bailey'}
# Olympic Olympic_sports
# 319 {'doc_title': '18_ATHLETICS', 'mention': 'Olympic', 'label': 'Olympic_sports'}
# Olympics Summer_Olympic_Games
# 321 {'doc_title': '18_ATHLETICS', 'mention': 'Olympics', 'label': 'Summer_Olympic_Games'}
# Mitchell Dennis_Mitchell
# 323 {'doc_title': '18_ATHLETICS', 'mention': 'Mitchell', 'label': 'Dennis_Mitchell'}
# Jamaican Jamaica
# 324 {'doc_title': '18_ATHLETICS', 'mention': 'Jamaican', 'label': 'Jamaica'}
# BERLIN Berlin
# 325 {'doc_title': '2_ATHLETICS', 'mention': 'BERLIN', 'label': 'Berlin'}
# Nice OGC_Nice
# 328 {'doc_title': '7_SOCCER', 'mention': 'Nice', 'label': 'OGC_Nice'}
# NICE OGC_Nice
# 329 {'doc_title': '7_SOCCER', 'mention': 'NICE', 'label': 'OGC_Nice'}
# NICE Nice
# 330 {'doc_title': '7_SOCCER', 'mention': 'NICE', 'label': 'Nice'}
# French France
# 332 {'doc_title': '7_SOCCER', 'mention': 'French', 'label': 'France'}
# Nice OGC_Nice
# 333 {'doc_title': '7_SOCCER', 'mention': 'Nice', 'label': 'OGC_Nice'}
# Nice OGC_Nice
# 334 {'doc_title': '7_SOCCER', 'mention': 'Nice', 'label': 'OGC_Nice'}
# COLOMBO Colombo
# 335 {'doc_title': '19_CRICKET', 'mention': 'COLOMBO', 'label': 'Colombo'}
# Australia Australia_national_cricket_team
# 336 {'doc_title': '19_CRICKET', 'mention': 'Australia', 'label': 'Australia_national_cricket_team'}
# SRI LANKA Sri_Lanka_national_cricket_team
# 337 {'doc_title': '21_CRICKET', 'mention': 'SRI LANKA', 'label': 'Sri_Lanka_national_cricket_team'}
# AUSTRALIA Australia_national_cricket_team
# 338 {'doc_title': '21_CRICKET', 'mention': 'AUSTRALIA', 'label': 'Australia_national_cricket_team'}
# COLOMBO Colombo
# 339 {'doc_title': '21_CRICKET', 'mention': 'COLOMBO', 'label': 'Colombo'}
# Sri Lanka Sri_Lanka_national_cricket_team
# 340 {'doc_title': '21_CRICKET', 'mention': 'Sri Lanka', 'label': 'Sri_Lanka_national_cricket_team'}
# Australia Australia_national_cricket_team
# 341 {'doc_title': '21_CRICKET', 'mention': 'Australia', 'label': 'Australia_national_cricket_team'}
# Australia Australia_national_cricket_team
# 342 {'doc_title': '21_CRICKET', 'mention': 'Australia', 'label': 'Australia_national_cricket_team'}
# Sri Lanka Sri_Lanka_national_cricket_team
# 343 {'doc_title': '21_CRICKET', 'mention': 'Sri Lanka', 'label': 'Sri_Lanka_national_cricket_team'}
# Sri Lanka Sri_Lanka_national_cricket_team
# 344 {'doc_title': '19_CRICKET', 'mention': 'Sri Lanka', 'label': 'Sri_Lanka_national_cricket_team'}
# Australia Australia_national_cricket_team
# 345 {'doc_title': '19_CRICKET', 'mention': 'Australia', 'label': 'Australia_national_cricket_team'}
# Sri Lanka Sri_Lanka_national_cricket_team
# 350 {'doc_title': '19_CRICKET', 'mention': 'Sri Lanka', 'label': 'Sri_Lanka_national_cricket_team'}
# POLISH Poland
# 351 {'doc_title': '22_POLISH', 'mention': 'POLISH', 'label': 'Poland'}
# WARSAW Warsaw
# 352 {'doc_title': '22_POLISH', 'mention': 'WARSAW', 'label': 'Warsaw'}
# NEW YORK New_York_City
# 353 {'doc_title': '23_NYMEX', 'mention': 'NEW YORK', 'label': 'New_York_City'}
# U.S. United_States
# 354 {'doc_title': '23_NYMEX', 'mention': 'U.S.', 'label': 'United_States'}
# Iraqi Iraq
# 359 {'doc_title': '24_Iraqi', 'mention': 'Iraqi', 'label': 'Iraq'}
# Sudanese Sudan
# 360 {'doc_title': '24_Iraqi', 'mention': 'Sudanese', 'label': 'Sudan'}
# LONDON London
# 361 {'doc_title': '24_Iraqi', 'mention': 'LONDON', 'label': 'London'}
# Iraqis Iraq
# 362 {'doc_title': '24_Iraqi', 'mention': 'Iraqis', 'label': 'Iraq'}
# Sudanese Sudan
# 363 {'doc_title': '24_Iraqi', 'mention': 'Sudanese', 'label': 'Sudan'}
# Britain United_Kingdom
# 365 {'doc_title': '24_Iraqi', 'mention': 'Britain', 'label': 'United_Kingdom'}
# Stansted Stansted_Mountfitchet
# 366 {'doc_title': '24_Iraqi', 'mention': 'Stansted', 'label': 'Stansted_Mountfitchet'}
# Iraqis Iraq
# 367 {'doc_title': '24_Iraqi', 'mention': 'Iraqis', 'label': 'Iraq'}
# Saddam Saddam_Hussein
# 368 {'doc_title': '24_Iraqi', 'mention': 'Saddam', 'label': 'Saddam_Hussein'}
# Hussein Saddam_Hussein
# 369 {'doc_title': '24_Iraqi', 'mention': 'Hussein', 'label': 'Saddam_Hussein'}
# English United_Kingdom
# 370 {'doc_title': '24_Iraqi', 'mention': 'English', 'label': 'United_Kingdom'}
# LONDON London
# 374 {'doc_title': '25_Late', 'mention': 'LONDON', 'label': 'London'}
# European Europe
# 375 {'doc_title': '25_Late', 'mention': 'European', 'label': 'Europe'}
# GERMANY Germany
# 376 {'doc_title': '25_Late', 'mention': 'GERMANY', 'label': 'Germany'}
# U.S. United_States
# 377 {'doc_title': '25_Late', 'mention': 'U.S.', 'label': 'United_States'}
# BRITAIN United_Kingdom
# 378 {'doc_title': '25_Late', 'mention': 'BRITAIN', 'label': 'United_Kingdom'}
# FRANCE France
# 379 {'doc_title': '25_Late', 'mention': 'FRANCE', 'label': 'France'}
# U.S. United_States
# 380 {'doc_title': '25_Late', 'mention': 'U.S.', 'label': 'United_States'}
# ITALY Italy
# 382 {'doc_title': '25_Late', 'mention': 'ITALY', 'label': 'Italy'}
# Treasuries United_States_Treasury_security
# 383 {'doc_title': '25_Late', 'mention': 'Treasuries', 'label': 'United_States_Treasury_security'}
# U.S. Treasury United_States_Department_of_the_Treasury
# 384 {'doc_title': '25_Late', 'mention': 'U.S. Treasury', 'label': 'United_States_Department_of_the_Treasury'}
# Labour Day Labor_Day
# 385 {'doc_title': '25_Late', 'mention': 'Labour Day', 'label': 'Labor_Day'}
# JAPAN Japan
# 387 {'doc_title': '25_Late', 'mention': 'JAPAN', 'label': 'Japan'}
# BOJ Bank_of_Japan
# 388 {'doc_title': '25_Late', 'mention': 'BOJ', 'label': 'Bank_of_Japan'}
# U.S. United_States
# 390 {'doc_title': '25_Late', 'mention': 'U.S.', 'label': 'United_States'}
# Labour Day Labor_Day
# 391 {'doc_title': '25_Late', 'mention': 'Labour Day', 'label': 'Labor_Day'}
# U.S. United_States
# 392 {'doc_title': '25_Late', 'mention': 'U.S.', 'label': 'United_States'}
# Japanese Japan
# 393 {'doc_title': '25_Late', 'mention': 'Japanese', 'label': 'Japan'}
# Norwegian Norway
# 394 {'doc_title': '25_Late', 'mention': 'Norwegian', 'label': 'Norway'}
# European European_Union
# 395 {'doc_title': '25_Late', 'mention': 'European', 'label': 'European_Union'}
# FRANCE France_national_football_team
# 396 {'doc_title': '29_SOCCER', 'mention': 'FRANCE', 'label': 'France_national_football_team'}
# MEXICO Mexico_national_football_team
# 397 {'doc_title': '29_SOCCER', 'mention': 'MEXICO', 'label': 'Mexico_national_football_team'}
# PARIS Paris
# 398 {'doc_title': '29_SOCCER', 'mention': 'PARIS', 'label': 'Paris'}
# Moslem Islam
# 399 {'doc_title': '30_Ruling', 'mention': 'Moslem', 'label': 'Islam'}
# SARAJEVO Sarajevo
# 400 {'doc_title': '30_Ruling', 'mention': 'SARAJEVO', 'label': 'Sarajevo'}
# France France_national_football_team
# 401 {'doc_title': '29_SOCCER', 'mention': 'France', 'label': 'France_national_football_team'}
# Moslem Islam
# 402 {'doc_title': '30_Ruling', 'mention': 'Moslem', 'label': 'Islam'}
# U.S. United_States
# 403 {'doc_title': '30_Ruling', 'mention': 'U.S.', 'label': 'United_States'}
# U.S. United_States
# 404 {'doc_title': '30_Ruling', 'mention': 'U.S.', 'label': 'United_States'}
# SDA Party_of_Democratic_Action
# 405 {'doc_title': '30_Ruling', 'mention': 'SDA', 'label': 'Party_of_Democratic_Action'}
# U.S. United_States
# 406 {'doc_title': '30_Ruling', 'mention': 'U.S.', 'label': 'United_States'}
# Mexico Mexico_national_football_team
# 407 {'doc_title': '29_SOCCER', 'mention': 'Mexico', 'label': 'Mexico_national_football_team'}
# SDA Party_of_Democratic_Action
# 409 {'doc_title': '30_Ruling', 'mention': 'SDA', 'label': 'Party_of_Democratic_Action'}
# Serb Serbia
# 410 {'doc_title': '30_Ruling', 'mention': 'Serb', 'label': 'Serbia'}
# SDA Party_of_Democratic_Action
# 411 {'doc_title': '30_Ruling', 'mention': 'SDA', 'label': 'Party_of_Democratic_Action'}
# BUCHAREST Bucharest
# 413 {'doc_title': '35_Romania', 'mention': 'BUCHAREST', 'label': 'Bucharest'}
# Cambodian Cambodia
# 414 {'doc_title': '36_Cambodian', 'mention': 'Cambodian', 'label': 'Cambodia'}
# French France
# 417 {'doc_title': '36_Cambodian', 'mention': 'French', 'label': 'France'}
# Sihanouk Norodom_Sihanouk
# 418 {'doc_title': '36_Cambodian', 'mention': 'Sihanouk', 'label': 'Norodom_Sihanouk'}
# Sihanouk Norodom_Sihanouk
# 419 {'doc_title': '36_Cambodian', 'mention': 'Sihanouk', 'label': 'Norodom_Sihanouk'}
# Dole Bob_Dole
# 421 {'doc_title': '38_Dole', 'mention': 'Dole', 'label': 'Bob_Dole'}
# Calif California
# 422 {'doc_title': '38_Dole', 'mention': 'Calif', 'label': 'California'}
# Clinton Bill_Clinton
# 423 {'doc_title': '38_Dole', 'mention': 'Clinton', 'label': 'Bill_Clinton'}
# Dole Bob_Dole
# 424 {'doc_title': '38_Dole', 'mention': 'Dole', 'label': 'Bob_Dole'}
# Clinton Bill_Clinton
# 425 {'doc_title': '38_Dole', 'mention': 'Clinton', 'label': 'Bill_Clinton'}
# Dole Bob_Dole
# 426 {'doc_title': '38_Dole', 'mention': 'Dole', 'label': 'Bob_Dole'}
# Dole Bob_Dole
# 427 {'doc_title': '38_Dole', 'mention': 'Dole', 'label': 'Bob_Dole'}
# Clinton Bill_Clinton
# 428 {'doc_title': '38_Dole', 'mention': 'Clinton', 'label': 'Bill_Clinton'}
# South Carolina Governor_of_South_Carolina
# 429 {'doc_title': '38_Dole', 'mention': 'South Carolina', 'label': 'Governor_of_South_Carolina'}
# Dole Bob_Dole
# 430 {'doc_title': '38_Dole', 'mention': 'Dole', 'label': 'Bob_Dole'}
# Dole Bob_Dole
# 431 {'doc_title': '38_Dole', 'mention': 'Dole', 'label': 'Bob_Dole'}
# Dole Bob_Dole
# 432 {'doc_title': '38_Dole', 'mention': 'Dole', 'label': 'Bob_Dole'}
# Reform Party Reform_Party_of_the_United_States_of_America
# 435 {'doc_title': '38_Dole', 'mention': 'Reform Party', 'label': 'Reform_Party_of_the_United_States_of_America'}
# BONN Bonn
# 439 {'doc_title': '40_Bonn', 'mention': 'BONN', 'label': 'Bonn'}
# German Germany
# 440 {'doc_title': '40_Bonn', 'mention': 'German', 'label': 'Germany'}
# Palestinians State_of_Palestine
# 442 {'doc_title': '40_Bonn', 'mention': 'Palestinians', 'label': 'State_of_Palestine'}
# Jewish Jews
# 445 {'doc_title': '40_Bonn', 'mention': 'Jewish', 'label': 'Jews'}
# Palestinian State_of_Palestine
# 448 {'doc_title': '40_Bonn', 'mention': 'Palestinian', 'label': 'State_of_Palestine'}
# Israeli Israel
# 450 {'doc_title': '40_Bonn', 'mention': 'Israeli', 'label': 'Israel'}
# German Germany
# 451 {'doc_title': '40_Bonn', 'mention': 'German', 'label': 'Germany'}
# Jewish Jews
# 456 {'doc_title': '40_Bonn', 'mention': 'Jewish', 'label': 'Jews'}
# Israeli Israel
# 457 {'doc_title': '40_Bonn', 'mention': 'Israeli', 'label': 'Israel'}
# German Germany
# 459 {'doc_title': '40_Bonn', 'mention': 'German', 'label': 'Germany'}
# Kinkel Klaus_Kinkel
# 460 {'doc_title': '40_Bonn', 'mention': 'Kinkel', 'label': 'Klaus_Kinkel'}
# Israeli Israel
# 462 {'doc_title': '40_Bonn', 'mention': 'Israeli', 'label': 'Israel'}
# Netanyahu Benjamin_Netanyahu
# 463 {'doc_title': '40_Bonn', 'mention': 'Netanyahu', 'label': 'Benjamin_Netanyahu'}
# German Germany
# 465 {'doc_title': '40_Bonn', 'mention': 'German', 'label': 'Germany'}
# Treorchy Treorchy_RFC
# 467 {'doc_title': '28_RUGBY', 'mention': 'Treorchy', 'label': 'Treorchy_RFC'}
# Israeli Israel
# 468 {'doc_title': '40_Bonn', 'mention': 'Israeli', 'label': 'Israel'}
# Israeli Israel
# 469 {'doc_title': '40_Bonn', 'mention': 'Israeli', 'label': 'Israel'}
# Netanyahu Benjamin_Netanyahu
# 470 {'doc_title': '40_Bonn', 'mention': 'Netanyahu', 'label': 'Benjamin_Netanyahu'}
# UKRAINE Ukraine_national_football_team
# 473 {'doc_title': '44_SOCCER', 'mention': 'UKRAINE', 'label': 'Ukraine_national_football_team'}
# NORTHERN IRELAND Northern_Ireland_national_football_team
# 474 {'doc_title': '44_SOCCER', 'mention': 'NORTHERN IRELAND', 'label': 'Northern_Ireland_national_football_team'}
# WORLD CUP 1998_FIFA_World_Cup
# 475 {'doc_title': '44_SOCCER', 'mention': 'WORLD CUP', 'label': '1998_FIFA_World_Cup'}
# BELFAST Belfast
# 476 {'doc_title': '44_SOCCER', 'mention': 'BELFAST', 'label': 'Belfast'}
# Ukraine Ukraine_national_football_team
# 477 {'doc_title': '44_SOCCER', 'mention': 'Ukraine', 'label': 'Ukraine_national_football_team'}
# Northern Ireland Northern_Ireland_national_football_team
# 478 {'doc_title': '44_SOCCER', 'mention': 'Northern Ireland', 'label': 'Northern_Ireland_national_football_team'}
# World Cup FIFA_World_Cup
# 479 {'doc_title': '44_SOCCER', 'mention': 'World Cup', 'label': 'FIFA_World_Cup'}
# European Europe
# 480 {'doc_title': '44_SOCCER', 'mention': 'European', 'label': 'Europe'}
# Palestinian State_of_Palestine
# 482 {'doc_title': '47_Israel', 'mention': 'Palestinian', 'label': 'State_of_Palestine'}
# Israeli Israel
# 483 {'doc_title': '47_Israel', 'mention': 'Israeli', 'label': 'Israel'}
# Palestinian State_of_Palestine
# 484 {'doc_title': '47_Israel', 'mention': 'Palestinian', 'label': 'State_of_Palestine'}
# SPANISH Spain
# 487 {'doc_title': '48_SOCCER', 'mention': 'SPANISH', 'label': 'Spain'}
# Israeli Israel
# 488 {'doc_title': '47_Israel', 'mention': 'Israeli', 'label': 'Israel'}
# Hebrew Hebrew_language
# 489 {'doc_title': '47_Israel', 'mention': 'Hebrew', 'label': 'Hebrew_language'}
# Palestinian State_of_Palestine
# 490 {'doc_title': '47_Israel', 'mention': 'Palestinian', 'label': 'State_of_Palestine'}
# MADRID Madrid
# 491 {'doc_title': '48_SOCCER', 'mention': 'MADRID', 'label': 'Madrid'}
# Arafat Yasser_Arafat
# 492 {'doc_title': '47_Israel', 'mention': 'Arafat', 'label': 'Yasser_Arafat'}
# Jewish Jews
# 494 {'doc_title': '47_Israel', 'mention': 'Jewish', 'label': 'Jews'}
# Spanish Spain
# 496 {'doc_title': '48_SOCCER', 'mention': 'Spanish', 'label': 'Spain'}
# Palestinian State_of_Palestine
# 497 {'doc_title': '47_Israel', 'mention': 'Palestinian', 'label': 'State_of_Palestine'}
# Gaza Gaza_Strip
# 498 {'doc_title': '47_Israel', 'mention': 'Gaza', 'label': 'Gaza_Strip'}
# Palestinians State_of_Palestine
# 499 {'doc_title': '47_Israel', 'mention': 'Palestinians', 'label': 'State_of_Palestine'}
# Moslem Islam
# 502 {'doc_title': '47_Israel', 'mention': 'Moslem', 'label': 'Islam'}
# Jewish Jews
# 503 {'doc_title': '47_Israel', 'mention': 'Jewish', 'label': 'Jews'}
# Israeli Israel
# 504 {'doc_title': '47_Israel', 'mention': 'Israeli', 'label': 'Israel'}
# Palestinian State_of_Palestine
# 507 {'doc_title': '47_Israel', 'mention': 'Palestinian', 'label': 'State_of_Palestine'}
# Palestinians State_of_Palestine
# 508 {'doc_title': '47_Israel', 'mention': 'Palestinians', 'label': 'State_of_Palestine'}
# Arafat Yasser_Arafat
# 509 {'doc_title': '47_Israel', 'mention': 'Arafat', 'label': 'Yasser_Arafat'}
# Israeli Israel
# 511 {'doc_title': '47_Israel', 'mention': 'Israeli', 'label': 'Israel'}
# Palestinians State_of_Palestine
# 515 {'doc_title': '47_Israel', 'mention': 'Palestinians', 'label': 'State_of_Palestine'}
# Israeli Israel
# 516 {'doc_title': '47_Israel', 'mention': 'Israeli', 'label': 'Israel'}
# Israelis Israel
# 517 {'doc_title': '47_Israel', 'mention': 'Israelis', 'label': 'Israel'}
# AMSTERDAM Amsterdam
# 518 {'doc_title': '50_Dutch', 'mention': 'AMSTERDAM', 'label': 'Amsterdam'}
# Arafat Yasser_Arafat
# 519 {'doc_title': '47_Israel', 'mention': 'Arafat', 'label': 'Yasser_Arafat'}
# Dutch Netherlands
# 520 {'doc_title': '50_Dutch', 'mention': 'Dutch', 'label': 'Netherlands'}
# Israelis Israel
# 521 {'doc_title': '47_Israel', 'mention': 'Israelis', 'label': 'Israel'}
# Commerce United_States_Department_of_Commerce
# 522 {'doc_title': '51_Consumer', 'mention': 'Commerce', 'label': 'United_States_Department_of_Commerce'}
# U.S. United_States
# 523 {'doc_title': '51_Consumer', 'mention': 'U.S.', 'label': 'United_States'}
# Wall Street New_York_Stock_Exchange
# 524 {'doc_title': '51_Consumer', 'mention': 'Wall Street', 'label': 'New_York_Stock_Exchange'}
# Dutch Netherlands
# 525 {'doc_title': '50_Dutch', 'mention': 'Dutch', 'label': 'Netherlands'}
# Dutch Netherlands
# 527 {'doc_title': '50_Dutch', 'mention': 'Dutch', 'label': 'Netherlands'}
# German Germany
# 528 {'doc_title': '50_Dutch', 'mention': 'German', 'label': 'Germany'}
# BONN Bonn
# 532 {'doc_title': '52_OSCE', 'mention': 'BONN', 'label': 'Bonn'}
# German Germany
# 534 {'doc_title': '52_OSCE', 'mention': 'German', 'label': 'Germany'}
# Russian Russia
# 537 {'doc_title': '52_OSCE', 'mention': 'Russian', 'label': 'Russia'}
# Swiss Switzerland
# 538 {'doc_title': '52_OSCE', 'mention': 'Swiss', 'label': 'Switzerland'}
# Swiss Switzerland
# 540 {'doc_title': '52_OSCE', 'mention': 'Swiss', 'label': 'Switzerland'}
# Russian Russia
# 542 {'doc_title': '52_OSCE', 'mention': 'Russian', 'label': 'Russia'}
# Russian Russia
# 552 {'doc_title': '52_OSCE', 'mention': 'Russian', 'label': 'Russia'}
# STOCKHOLM Stockholm
# 553 {'doc_title': '39_Ericsson', 'mention': 'STOCKHOLM', 'label': 'Stockholm'}
# Swedish Sweden
# 554 {'doc_title': '39_Ericsson', 'mention': 'Swedish', 'label': 'Sweden'}
# Tsang Donald_Tsang
# 558 {'doc_title': '53_HK', 'mention': 'Tsang', 'label': 'Donald_Tsang'}
# AUCKLAND Auckland
# 559 {'doc_title': '53_HK', 'mention': 'AUCKLAND', 'label': 'Auckland'}
# Tsang Donald_Tsang
# 561 {'doc_title': '53_HK', 'mention': 'Tsang', 'label': 'Donald_Tsang'}
# Britain United_Kingdom
# 565 {'doc_title': '53_HK', 'mention': 'Britain', 'label': 'United_Kingdom'}
# Tsang Donald_Tsang
# 567 {'doc_title': '53_HK', 'mention': 'Tsang', 'label': 'Donald_Tsang'}
# TOKYO Tokyo
# 572 {'doc_title': '55_Jeans', 'mention': 'TOKYO', 'label': 'Tokyo'}
# IRISH Republic_of_Ireland_national_football_team
# 573 {'doc_title': '61_SOCCER', 'mention': 'IRISH', 'label': 'Republic_of_Ireland_national_football_team'}
# ESCHEN Eschen
# 574 {'doc_title': '61_SOCCER', 'mention': 'ESCHEN', 'label': 'Eschen'}
# Republic of Ireland Republic_of_Ireland_national_football_team
# 576 {'doc_title': '61_SOCCER', 'mention': 'Republic of Ireland', 'label': 'Republic_of_Ireland_national_football_team'}
# World Cup 1998_FIFA_World_Cup
# 578 {'doc_title': '61_SOCCER', 'mention': 'World Cup', 'label': '1998_FIFA_World_Cup'}
# Irish Republic_of_Ireland_national_football_team
# 579 {'doc_title': '61_SOCCER', 'mention': 'Irish', 'label': 'Republic_of_Ireland_national_football_team'}
# Quinn Niall_Quinn
# 582 {'doc_title': '61_SOCCER', 'mention': 'Quinn', 'label': 'Niall_Quinn'}
# Ireland Republic_of_Ireland_national_football_team
# 583 {'doc_title': '61_SOCCER', 'mention': 'Ireland', 'label': 'Republic_of_Ireland_national_football_team'}
# Irish Republic_of_Ireland_national_football_team
# 584 {'doc_title': '61_SOCCER', 'mention': 'Irish', 'label': 'Republic_of_Ireland_national_football_team'}
# Ireland Republic_of_Ireland_national_football_team
# 585 {'doc_title': '61_SOCCER', 'mention': 'Ireland', 'label': 'Republic_of_Ireland_national_football_team'}
# LANDGRAAF Landgraaf
# 587 {'doc_title': '62_CYCLING', 'mention': 'LANDGRAAF', 'label': 'Landgraaf'}
# Polti Team_Polti
# 594 {'doc_title': '62_CYCLING', 'mention': 'Polti', 'label': 'Team_Polti'}
# Gloucester Gloucester_Rugby
# 595 {'doc_title': '28_RUGBY', 'mention': 'Gloucester', 'label': 'Gloucester_Rugby'}
# Bristol Bristol_Rugby
# 601 {'doc_title': '28_RUGBY', 'mention': 'Bristol', 'label': 'Bristol_Rugby'}
# Northampton Northampton_Saints
# 606 {'doc_title': '28_RUGBY', 'mention': 'Northampton', 'label': 'Northampton_Saints'}
# U.S. United_States
# 609 {'doc_title': '62_CYCLING', 'mention': 'U.S.', 'label': 'United_States'}
# Ekimov Viatcheslav_Ekimov
# 610 {'doc_title': '62_CYCLING', 'mention': 'Ekimov', 'label': 'Viatcheslav_Ekimov'}
# Ludwig Olaf_Ludwig
# 613 {'doc_title': '62_CYCLING', 'mention': 'Ludwig', 'label': 'Olaf_Ludwig'}
# Ebbw Vale Ebbw_Vale_RFC
# 615 {'doc_title': '28_RUGBY', 'mention': 'Ebbw Vale', 'label': 'Ebbw_Vale_RFC'}
# Skibby Jesper_Skibby
# 616 {'doc_title': '62_CYCLING', 'mention': 'Skibby', 'label': 'Jesper_Skibby'}
# SCOTTISH Scotland
# 617 {'doc_title': '28_RUGBY', 'mention': 'SCOTTISH', 'label': 'Scotland'}
# WELSH Wales
# 618 {'doc_title': '28_RUGBY', 'mention': 'WELSH', 'label': 'Wales'}
# ESSEX Essex_County_Cricket_Club
# 619 {'doc_title': '64_CRICKET', 'mention': 'ESSEX', 'label': 'Essex_County_Cricket_Club'}
# KENT Kent_County_Cricket_Club
# 620 {'doc_title': '64_CRICKET', 'mention': 'KENT', 'label': 'Kent_County_Cricket_Club'}
# LONDON London
# 621 {'doc_title': '64_CRICKET', 'mention': 'LONDON', 'label': 'London'}
# Essex Essex_County_Cricket_Club
# 622 {'doc_title': '64_CRICKET', 'mention': 'Essex', 'label': 'Essex_County_Cricket_Club'}
# Kent Kent_County_Cricket_Club
# 623 {'doc_title': '64_CRICKET', 'mention': 'Kent', 'label': 'Kent_County_Cricket_Club'}
# LONDON London
# 624 {'doc_title': '28_RUGBY', 'mention': 'LONDON', 'label': 'London'}
# Derbyshire Derbyshire_County_Cricket_Club
# 625 {'doc_title': '64_CRICKET', 'mention': 'Derbyshire', 'label': 'Derbyshire_County_Cricket_Club'}
# Surrey Surrey_County_Cricket_Club
# 626 {'doc_title': '64_CRICKET', 'mention': 'Surrey', 'label': 'Surrey_County_Cricket_Club'}
# English England
# 627 {'doc_title': '64_CRICKET', 'mention': 'English', 'label': 'England'}
# Essex Essex_County_Cricket_Club
# 628 {'doc_title': '64_CRICKET', 'mention': 'Essex', 'label': 'Essex_County_Cricket_Club'}
# Yorkshire Yorkshire_County_Cricket_Club
# 629 {'doc_title': '64_CRICKET', 'mention': 'Yorkshire', 'label': 'Yorkshire_County_Cricket_Club'}
# Kent Kent_County_Cricket_Club
# 630 {'doc_title': '64_CRICKET', 'mention': 'Kent', 'label': 'Kent_County_Cricket_Club'}
# Nottinghamshire Nottinghamshire_County_Cricket_Club
# 631 {'doc_title': '64_CRICKET', 'mention': 'Nottinghamshire', 'label': 'Nottinghamshire_County_Cricket_Club'}
# Tunbridge Wells Royal_Tunbridge_Wells
# 632 {'doc_title': '64_CRICKET', 'mention': 'Tunbridge Wells', 'label': 'Royal_Tunbridge_Wells'}
# Derbyshire Derbyshire_County_Cricket_Club
# 633 {'doc_title': '64_CRICKET', 'mention': 'Derbyshire', 'label': 'Derbyshire_County_Cricket_Club'}
# Worcestershire Worcestershire_County_Cricket_Club
# 634 {'doc_title': '64_CRICKET', 'mention': 'Worcestershire', 'label': 'Worcestershire_County_Cricket_Club'}
# Surrey Surrey_County_Cricket_Club
# 635 {'doc_title': '64_CRICKET', 'mention': 'Surrey', 'label': 'Surrey_County_Cricket_Club'}
# Warwickshire Warwickshire_County_Cricket_Club
# 636 {'doc_title': '64_CRICKET', 'mention': 'Warwickshire', 'label': 'Warwickshire_County_Cricket_Club'}
# Leicestershire Leicestershire_County_Cricket_Club
# 637 {'doc_title': '64_CRICKET', 'mention': 'Leicestershire', 'label': 'Leicestershire_County_Cricket_Club'}
# Warwickshire Warwickshire_County_Cricket_Club
# 638 {'doc_title': '64_CRICKET', 'mention': 'Warwickshire', 'label': 'Warwickshire_County_Cricket_Club'}
# Surrey Surrey_County_Cricket_Club
# 639 {'doc_title': '64_CRICKET', 'mention': 'Surrey', 'label': 'Surrey_County_Cricket_Club'}
# Australian Australia
# 640 {'doc_title': '64_CRICKET', 'mention': 'Australian', 'label': 'Australia'}
# Derbyshire Derbyshire_County_Cricket_Club
# 641 {'doc_title': '64_CRICKET', 'mention': 'Derbyshire', 'label': 'Derbyshire_County_Cricket_Club'}
# Australian Australia
# 642 {'doc_title': '64_CRICKET', 'mention': 'Australian', 'label': 'Australia'}
# English England
# 643 {'doc_title': '28_RUGBY', 'mention': 'English', 'label': 'England'}
# Scottish Scotland
# 644 {'doc_title': '28_RUGBY', 'mention': 'Scottish', 'label': 'Scotland'}
# Welsh Wales
# 645 {'doc_title': '28_RUGBY', 'mention': 'Welsh', 'label': 'Wales'}
# RUGBY UNION Rugby_union
# 646 {'doc_title': '28_RUGBY', 'mention': 'RUGBY UNION', 'label': 'Rugby_union'}
# ENGLISH England
# 647 {'doc_title': '28_RUGBY', 'mention': 'ENGLISH', 'label': 'England'}
# Bath Bath_Rugby
# 648 {'doc_title': '28_RUGBY', 'mention': 'Bath', 'label': 'Bath_Rugby'}
# Sale Sale_Sharks
# 649 {'doc_title': '28_RUGBY', 'mention': 'Sale', 'label': 'Sale_Sharks'}
# Leicester Leicester_Tigers
# 650 {'doc_title': '28_RUGBY', 'mention': 'Leicester', 'label': 'Leicester_Tigers'}
# Welsh Wales
# 651 {'doc_title': '28_RUGBY', 'mention': 'Welsh', 'label': 'Wales'}
# Bridgend Bridgend_Ravens
# 652 {'doc_title': '28_RUGBY', 'mention': 'Bridgend', 'label': 'Bridgend_Ravens'}
# Llanelli Llanelli_RFC
# 653 {'doc_title': '28_RUGBY', 'mention': 'Llanelli', 'label': 'Llanelli_RFC'}
# Dunvant Dunvant_RFC
# 654 {'doc_title': '28_RUGBY', 'mention': 'Dunvant', 'label': 'Dunvant_RFC'}
# Newbridge Newbridge_RFC
# 655 {'doc_title': '28_RUGBY', 'mention': 'Newbridge', 'label': 'Newbridge_RFC'}
# Newport Newport_RFC
# 656 {'doc_title': '28_RUGBY', 'mention': 'Newport', 'label': 'Newport_RFC'}
# Caerphilly Caerphilly_RFC
# 657 {'doc_title': '28_RUGBY', 'mention': 'Caerphilly', 'label': 'Caerphilly_RFC'}
# Swansea Swansea_RFC
# 658 {'doc_title': '28_RUGBY', 'mention': 'Swansea', 'label': 'Swansea_RFC'}
# Cardiff Cardiff_RFC
# 659 {'doc_title': '28_RUGBY', 'mention': 'Cardiff', 'label': 'Cardiff_RFC'}
# Scottish Scotland
# 660 {'doc_title': '28_RUGBY', 'mention': 'Scottish', 'label': 'Scotland'}
# Boroughmuir Boroughmuir_RFC
# 661 {'doc_title': '28_RUGBY', 'mention': 'Boroughmuir', 'label': 'Boroughmuir_RFC'}
# Hawick Hawick_RFC
# 662 {'doc_title': '28_RUGBY', 'mention': 'Hawick', 'label': 'Hawick_RFC'}
# Currie Currie_RFC
# 663 {'doc_title': '28_RUGBY', 'mention': 'Currie', 'label': 'Currie_RFC'}
# Melrose Melrose_RFC
# 664 {'doc_title': '28_RUGBY', 'mention': 'Melrose', 'label': 'Melrose_RFC'}
# RUGBY UNION Rugby_union
# 665 {'doc_title': '65_RUGBY', 'mention': 'RUGBY UNION', 'label': 'Rugby_union'}
# LYNAGH Michael_Lynagh
# 666 {'doc_title': '65_RUGBY', 'mention': 'LYNAGH', 'label': 'Michael_Lynagh'}
# DWYER Bob_Dwyer
# 667 {'doc_title': '65_RUGBY', 'mention': 'DWYER', 'label': 'Bob_Dwyer'}
# LEICESTER Leicester_Tigers
# 668 {'doc_title': '65_RUGBY', 'mention': 'LEICESTER', 'label': 'Leicester_Tigers'}
# LONDON London
# 669 {'doc_title': '65_RUGBY', 'mention': 'LONDON', 'label': 'London'}
# Wallaby Australia_national_rugby_union_team
# 670 {'doc_title': '65_RUGBY', 'mention': 'Wallaby', 'label': 'Australia_national_rugby_union_team'}
# English England
# 671 {'doc_title': '65_RUGBY', 'mention': 'English', 'label': 'England'}
# Leicester Leicester_Tigers
# 672 {'doc_title': '65_RUGBY', 'mention': 'Leicester', 'label': 'Leicester_Tigers'}
# Lynagh Michael_Lynagh
# 673 {'doc_title': '65_RUGBY', 'mention': 'Lynagh', 'label': 'Michael_Lynagh'}
# French France
# 675 {'doc_title': '65_RUGBY', 'mention': 'French', 'label': 'France'}
# Lynagh Michael_Lynagh
# 676 {'doc_title': '65_RUGBY', 'mention': 'Lynagh', 'label': 'Michael_Lynagh'}
# England England_national_rugby_union_team
# 677 {'doc_title': '65_RUGBY', 'mention': 'England', 'label': 'England_national_rugby_union_team'}
# French France
# 678 {'doc_title': '65_RUGBY', 'mention': 'French', 'label': 'France'}
# Gloucester Gloucester_Rugby
# 679 {'doc_title': '65_RUGBY', 'mention': 'Gloucester', 'label': 'Gloucester_Rugby'}
# England England_national_rugby_union_team
# 680 {'doc_title': '65_RUGBY', 'mention': 'England', 'label': 'England_national_rugby_union_team'}
# Bath Bath_Rugby
# 682 {'doc_title': '65_RUGBY', 'mention': 'Bath', 'label': 'Bath_Rugby'}
# Northampton Northampton_Saints
# 683 {'doc_title': '65_RUGBY', 'mention': 'Northampton', 'label': 'Northampton_Saints'}
# Bristol Bristol_Rugby
# 684 {'doc_title': '65_RUGBY', 'mention': 'Bristol', 'label': 'Bristol_Rugby'}
# SCOTTISH Scotland
# 686 {'doc_title': '31_SOCCER', 'mention': 'SCOTTISH', 'label': 'Scotland'}
# GLASGOW Glasgow
# 687 {'doc_title': '31_SOCCER', 'mention': 'GLASGOW', 'label': 'Glasgow'}
# Scottish Scotland
# 688 {'doc_title': '31_SOCCER', 'mention': 'Scottish', 'label': 'Scotland'}
# VANCOUVER Vancouver
# 689 {'doc_title': '67_MOTOR', 'mention': 'VANCOUVER', 'label': 'Vancouver'}
# INDYCAR IndyCar_Series
# 690 {'doc_title': '67_MOTOR', 'mention': 'INDYCAR', 'label': 'IndyCar_Series'}
# VANCOUVER Vancouver
# 691 {'doc_title': '67_MOTOR', 'mention': 'VANCOUVER', 'label': 'Vancouver'}
# IndyCar IndyCar_Series
# 693 {'doc_title': '67_MOTOR', 'mention': 'IndyCar', 'label': 'IndyCar_Series'}
# U.S. United_States
# 695 {'doc_title': '67_MOTOR', 'mention': 'U.S.', 'label': 'United_States'}
# U.S. United_States
# 696 {'doc_title': '67_MOTOR', 'mention': 'U.S.', 'label': 'United_States'}
# U.S. United_States
# 697 {'doc_title': '67_MOTOR', 'mention': 'U.S.', 'label': 'United_States'}
# U.S. United_States
# 698 {'doc_title': '67_MOTOR', 'mention': 'U.S.', 'label': 'United_States'}
# U.S. United_States
# 700 {'doc_title': '67_MOTOR', 'mention': 'U.S.', 'label': 'United_States'}
# YUGOSLAV Yugoslavia
# 704 {'doc_title': '70_SOCCER', 'mention': 'YUGOSLAV', 'label': 'Yugoslavia'}
# BELGRADE Belgrade
# 705 {'doc_title': '70_SOCCER', 'mention': 'BELGRADE', 'label': 'Belgrade'}
# Yugoslav Yugoslavia
# 706 {'doc_title': '70_SOCCER', 'mention': 'Yugoslav', 'label': 'Yugoslavia'}
# Hajduk FK_Hajduk_Kula
# 707 {'doc_title': '70_SOCCER', 'mention': 'Hajduk', 'label': 'FK_Hajduk_Kula'}
# Zemun FK_Zemun
# 708 {'doc_title': '70_SOCCER', 'mention': 'Zemun', 'label': 'FK_Zemun'}
# Rad FK_Rad
# 709 {'doc_title': '70_SOCCER', 'mention': 'Rad', 'label': 'FK_Rad'}
# Vojvodina FK_Vojvodina
# 710 {'doc_title': '70_SOCCER', 'mention': 'Vojvodina', 'label': 'FK_Vojvodina'}
# Red Star Red_Star_Belgrade
# 711 {'doc_title': '70_SOCCER', 'mention': 'Red Star', 'label': 'Red_Star_Belgrade'}
# Partizan FK_Partizan
# 712 {'doc_title': '70_SOCCER', 'mention': 'Partizan', 'label': 'FK_Partizan'}
# Red Star Red_Star_Belgrade
# 713 {'doc_title': '70_SOCCER', 'mention': 'Red Star', 'label': 'Red_Star_Belgrade'}
# Partizan FK_Partizan
# 714 {'doc_title': '70_SOCCER', 'mention': 'Partizan', 'label': 'FK_Partizan'}
# Vojvodina FK_Vojvodina
# 715 {'doc_title': '70_SOCCER', 'mention': 'Vojvodina', 'label': 'FK_Vojvodina'}
# Hajduk FK_Hajduk_Kula
# 716 {'doc_title': '70_SOCCER', 'mention': 'Hajduk', 'label': 'FK_Hajduk_Kula'}
# Zemun FK_Zemun
# 717 {'doc_title': '70_SOCCER', 'mention': 'Zemun', 'label': 'FK_Zemun'}
# Sloboda FK_Sloboda_Tuzla
# 718 {'doc_title': '70_SOCCER', 'mention': 'Sloboda', 'label': 'FK_Sloboda_Tuzla'}
# Rudar FK_Rudar_Ugljevik
# 719 {'doc_title': '70_SOCCER', 'mention': 'Rudar', 'label': 'FK_Rudar_Ugljevik'}
# Spartak FK_Spartak_Zlatibor_Voda
# 720 {'doc_title': '70_SOCCER', 'mention': 'Spartak', 'label': 'FK_Spartak_Zlatibor_Voda'}
# Sloboda FK_Sloboda_Tuzla
# 721 {'doc_title': '70_SOCCER', 'mention': 'Sloboda', 'label': 'FK_Sloboda_Tuzla'}
# Spartak FK_Spartak_Zlatibor_Voda
# 722 {'doc_title': '70_SOCCER', 'mention': 'Spartak', 'label': 'FK_Spartak_Zlatibor_Voda'}
# Rudar FK_Rudar_Ugljevik
# 723 {'doc_title': '70_SOCCER', 'mention': 'Rudar', 'label': 'FK_Rudar_Ugljevik'}
# HONG KONG Hong_Kong
# 724 {'doc_title': '71_SQUASH', 'mention': 'HONG KONG', 'label': 'Hong_Kong'}
# Australian Australia
# 725 {'doc_title': '71_SQUASH', 'mention': 'Australian', 'label': 'Australia'}
# Australian Australia
# 726 {'doc_title': '71_SQUASH', 'mention': 'Australian', 'label': 'Australia'}
# Eyles Rodney_Eyles
# 727 {'doc_title': '71_SQUASH', 'mention': 'Eyles', 'label': 'Rodney_Eyles'}
# Eyles Rodney_Eyles
# 729 {'doc_title': '71_SQUASH', 'mention': 'Eyles', 'label': 'Rodney_Eyles'}
# Eyles Rodney_Eyles
# 730 {'doc_title': '71_SQUASH', 'mention': 'Eyles', 'label': 'Rodney_Eyles'}
# El Salvador El_Salvador_national_football_team
# 731 {'doc_title': '73_SOCCER', 'mention': 'El Salvador', 'label': 'El_Salvador_national_football_team'}
# EL SALVADOR El_Salvador_national_football_team
# 732 {'doc_title': '73_SOCCER', 'mention': 'EL SALVADOR', 'label': 'El_Salvador_national_football_team'}
# LOS ANGELES Los_Angeles
# 733 {'doc_title': '73_SOCCER', 'mention': 'LOS ANGELES', 'label': 'Los_Angeles'}
# El Salvador El_Salvador_national_football_team
# 734 {'doc_title': '73_SOCCER', 'mention': 'El Salvador', 'label': 'El_Salvador_national_football_team'}
# MAJOR LEAGUE Major_League_Baseball
# 736 {'doc_title': '74_BASEBALL', 'mention': 'MAJOR LEAGUE', 'label': 'Major_League_Baseball'}
# NEW YORK New_York_City
# 737 {'doc_title': '74_BASEBALL', 'mention': 'NEW YORK', 'label': 'New_York_City'}
# Major League Major_League_Baseball
# 738 {'doc_title': '74_BASEBALL', 'mention': 'Major League', 'label': 'Major_League_Baseball'}
# DETROIT Detroit_Tigers
# 740 {'doc_title': '74_BASEBALL', 'mention': 'DETROIT', 'label': 'Detroit_Tigers'}
# Kansas City Kansas_City_Royals
# 741 {'doc_title': '74_BASEBALL', 'mention': 'Kansas City', 'label': 'Kansas_City_Royals'}
# Chicago Chicago_White_Sox
# 742 {'doc_title': '74_BASEBALL', 'mention': 'Chicago', 'label': 'Chicago_White_Sox'}
# TORONTO Toronto_Blue_Jays
# 743 {'doc_title': '74_BASEBALL', 'mention': 'TORONTO', 'label': 'Toronto_Blue_Jays'}
# MILWAUKEE Milwaukee_Brewers
# 744 {'doc_title': '74_BASEBALL', 'mention': 'MILWAUKEE', 'label': 'Milwaukee_Brewers'}
# Minnesota Minnesota_Twins
# 745 {'doc_title': '74_BASEBALL', 'mention': 'Minnesota', 'label': 'Minnesota_Twins'}
# Cleveland Cleveland_Indians
# 746 {'doc_title': '74_BASEBALL', 'mention': 'Cleveland', 'label': 'Cleveland_Indians'}
# New York New_York_Yankees
# 747 {'doc_title': '74_BASEBALL', 'mention': 'New York', 'label': 'New_York_Yankees'}
# CALIFORNIA Los_Angeles_Angels_of_Anaheim
# 748 {'doc_title': '74_BASEBALL', 'mention': 'CALIFORNIA', 'label': 'Los_Angeles_Angels_of_Anaheim'}
# OAKLAND Oakland_Athletics
# 749 {'doc_title': '74_BASEBALL', 'mention': 'OAKLAND', 'label': 'Oakland_Athletics'}
# Boston Boston_Red_Sox
# 750 {'doc_title': '74_BASEBALL', 'mention': 'Boston', 'label': 'Boston_Red_Sox'}
# Baltimore Baltimore_Orioles
# 751 {'doc_title': '74_BASEBALL', 'mention': 'Baltimore', 'label': 'Baltimore_Orioles'}
# SEATTLE Seattle_Mariners
# 752 {'doc_title': '74_BASEBALL', 'mention': 'SEATTLE', 'label': 'Seattle_Mariners'}
# CHICAGO Chicago_White_Sox
# 754 {'doc_title': '74_BASEBALL', 'mention': 'CHICAGO', 'label': 'Chicago_White_Sox'}
# Atlanta Atlanta_Braves
# 755 {'doc_title': '74_BASEBALL', 'mention': 'Atlanta', 'label': 'Atlanta_Braves'}
# Atlanta Atlanta_Braves
# 756 {'doc_title': '74_BASEBALL', 'mention': 'Atlanta', 'label': 'Atlanta_Braves'}
# CHICAGO Chicago_White_Sox
# 757 {'doc_title': '74_BASEBALL', 'mention': 'CHICAGO', 'label': 'Chicago_White_Sox'}
# CINCINNATI Cincinnati_Reds
# 758 {'doc_title': '74_BASEBALL', 'mention': 'CINCINNATI', 'label': 'Cincinnati_Reds'}
# San Diego San_Diego_Padres
# 759 {'doc_title': '74_BASEBALL', 'mention': 'San Diego', 'label': 'San_Diego_Padres'}
# MONTREAL Montreal_Expos
# 760 {'doc_title': '74_BASEBALL', 'mention': 'MONTREAL', 'label': 'Montreal_Expos'}
# Los Angeles Los_Angeles_Dodgers
# 761 {'doc_title': '74_BASEBALL', 'mention': 'Los Angeles', 'label': 'Los_Angeles_Dodgers'}
# PHILADELPHIA Philadelphia_Phillies
# 762 {'doc_title': '74_BASEBALL', 'mention': 'PHILADELPHIA', 'label': 'Philadelphia_Phillies'}
# Houston Houston_Astros
# 763 {'doc_title': '74_BASEBALL', 'mention': 'Houston', 'label': 'Houston_Astros'}
# PITTSBURGH Pittsburgh_Pirates
# 764 {'doc_title': '74_BASEBALL', 'mention': 'PITTSBURGH', 'label': 'Pittsburgh_Pirates'}
# San Francisco San_Francisco_Giants
# 765 {'doc_title': '74_BASEBALL', 'mention': 'San Francisco', 'label': 'San_Francisco_Giants'}
# NEW YORK New_York_Yankees
# 766 {'doc_title': '74_BASEBALL', 'mention': 'NEW YORK', 'label': 'New_York_Yankees'}
# Colorado Colorado_Rockies
# 767 {'doc_title': '74_BASEBALL', 'mention': 'Colorado', 'label': 'Colorado_Rockies'}
# Iraqis Iraq
# 768 {'doc_title': '81_Opposition', 'mention': 'Iraqis', 'label': 'Iraq'}
# LONDON London
# 770 {'doc_title': '81_Opposition', 'mention': 'LONDON', 'label': 'London'}
# Iraqi Iraq
# 771 {'doc_title': '81_Opposition', 'mention': 'Iraqi', 'label': 'Iraq'}
# Iraqi Iraq
# 772 {'doc_title': '81_Opposition', 'mention': 'Iraqi', 'label': 'Iraq'}
# Kurdish Kurdistan
# 773 {'doc_title': '81_Opposition', 'mention': 'Kurdish', 'label': 'Kurdistan'}
# Iraqi Iraq
# 776 {'doc_title': '81_Opposition', 'mention': 'Iraqi', 'label': 'Iraq'}
# Iraqi Iraq
# 777 {'doc_title': '81_Opposition', 'mention': 'Iraqi', 'label': 'Iraq'}
# Kurdish Kurdistan
# 778 {'doc_title': '81_Opposition', 'mention': 'Kurdish', 'label': 'Kurdistan'}
# GMT Greenwich_Mean_Time
# 781 {'doc_title': '81_Opposition', 'mention': 'GMT', 'label': 'Greenwich_Mean_Time'}
# Iraqi Iraq
# 782 {'doc_title': '81_Opposition', 'mention': 'Iraqi', 'label': 'Iraq'}
# Kurdish Kurdistan
# 784 {'doc_title': '81_Opposition', 'mention': 'Kurdish', 'label': 'Kurdistan'}
# U.S. United_States
# 786 {'doc_title': '81_Opposition', 'mention': 'U.S.', 'label': 'United_States'}
# Iraqi Iraq
# 787 {'doc_title': '81_Opposition', 'mention': 'Iraqi', 'label': 'Iraq'}
# Iraqi Kurdish Iraqi_Kurdistan
# 793 {'doc_title': '81_Opposition', 'mention': 'Iraqi Kurdish', 'label': 'Iraqi_Kurdistan'}
# SEOUL Seoul
# 794 {'doc_title': '80_Baseball-Results', 'mention': 'SEOUL', 'label': 'Seoul'}
# South Korean South_Korea
# 795 {'doc_title': '80_Baseball-Results', 'mention': 'South Korean', 'label': 'South_Korea'}
# Hanwha Hanwha_Eagles
# 796 {'doc_title': '80_Baseball-Results', 'mention': 'Hanwha', 'label': 'Hanwha_Eagles'}
# Moslem Islam
# 798 {'doc_title': '82_NATO', 'mention': 'Moslem', 'label': 'Islam'}
# MAHALA Mahala
# 799 {'doc_title': '82_NATO', 'mention': 'MAHALA', 'label': 'Mahala'}
# Moslem Islam
# 801 {'doc_title': '82_NATO', 'mention': 'Moslem', 'label': 'Islam'}
# Serb Serbia
# 803 {'doc_title': '82_NATO', 'mention': 'Serb', 'label': 'Serbia'}
# Moslem Islam
# 805 {'doc_title': '82_NATO', 'mention': 'Moslem', 'label': 'Islam'}
# Moslem Islam
# 813 {'doc_title': '82_NATO', 'mention': 'Moslem', 'label': 'Islam'}
# Moslems Islam
# 814 {'doc_title': '82_NATO', 'mention': 'Moslems', 'label': 'Islam'}
# Moslems Islam
# 815 {'doc_title': '82_NATO', 'mention': 'Moslems', 'label': 'Islam'}
# Moslems Islam
# 816 {'doc_title': '82_NATO', 'mention': 'Moslems', 'label': 'Islam'}
# Serb Serbia
# 817 {'doc_title': '82_NATO', 'mention': 'Serb', 'label': 'Serbia'}
# U.N. United_Nations
# 822 {'doc_title': '82_NATO', 'mention': 'U.N.', 'label': 'United_Nations'}
# Polish Poland
# 824 {'doc_title': '83_Polish', 'mention': 'Polish', 'label': 'Poland'}
# WARSAW Warsaw
# 825 {'doc_title': '83_Polish', 'mention': 'WARSAW', 'label': 'Warsaw'}
# Polish Poland
# 826 {'doc_title': '83_Polish', 'mention': 'Polish', 'label': 'Poland'}
# Polish Poland
# 828 {'doc_title': '83_Polish', 'mention': 'Polish', 'label': 'Poland'}
# Polish Poland
# 829 {'doc_title': '83_Polish', 'mention': 'Polish', 'label': 'Poland'}
# Polish Poland
# 831 {'doc_title': '83_Polish', 'mention': 'Polish', 'label': 'Poland'}
# French France
# 832 {'doc_title': '83_Polish', 'mention': 'French', 'label': 'France'}
# Polish Poland
# 836 {'doc_title': '83_Polish', 'mention': 'Polish', 'label': 'Poland'}
# Polish Poland
# 838 {'doc_title': '83_Polish', 'mention': 'Polish', 'label': 'Poland'}
# Swiss Switzerland
# 839 {'doc_title': '83_Polish', 'mention': 'Swiss', 'label': 'Switzerland'}
# Swiss Switzerland
# 840 {'doc_title': '83_Polish', 'mention': 'Swiss', 'label': 'Switzerland'}
# Cuban Cuba
# 841 {'doc_title': '84_Cuban', 'mention': 'Cuban', 'label': 'Cuba'}
# HAVANA Havana
# 842 {'doc_title': '84_Cuban', 'mention': 'HAVANA', 'label': 'Havana'}
# Cuban Cuba
# 844 {'doc_title': '84_Cuban', 'mention': 'Cuban', 'label': 'Cuba'}
# America United_States
# 847 {'doc_title': '84_Cuban', 'mention': 'America', 'label': 'United_States'}
# Philippine Philippines
# 849 {'doc_title': '86_Manila', 'mention': 'Philippine', 'label': 'Philippines'}
# Indonesian Indonesia
# 850 {'doc_title': '86_Manila', 'mention': 'Indonesian', 'label': 'Indonesia'}
# Iraqi Iraq
# 852 {'doc_title': '87_KPD', 'mention': 'Iraqi', 'label': 'Iraq'}
# Moslem Islam
# 853 {'doc_title': '86_Manila', 'mention': 'Moslem', 'label': 'Islam'}
# Philippine Philippines
# 856 {'doc_title': '86_Manila', 'mention': 'Philippine', 'label': 'Philippines'}
# BEIJING Beijing
# 858 {'doc_title': '89_China', 'mention': 'BEIJING', 'label': 'Beijing'}
# BEIJING Beijing
# 859 {'doc_title': '90_Chinese', 'mention': 'BEIJING', 'label': 'Beijing'}
# New York-based New_York
# 860 {'doc_title': '89_China', 'mention': 'New York-based', 'label': 'New_York'}
# New York-based New_York
# 861 {'doc_title': '90_Chinese', 'mention': 'New York-based', 'label': 'New_York'}
# KDP Kurdistan_Democratic_Party
# 862 {'doc_title': '87_KPD', 'mention': 'KDP', 'label': 'Kurdistan_Democratic_Party'}
# KDP Kurdistan_Democratic_Party
# 865 {'doc_title': '87_KPD', 'mention': 'KDP', 'label': 'Kurdistan_Democratic_Party'}
# KDP Kurdistan_Democratic_Party
# 872 {'doc_title': '87_KPD', 'mention': 'KDP', 'label': 'Kurdistan_Democratic_Party'}
# JERUSALEM Jerusalem
# 874 {'doc_title': '92_Ceasefire', 'mention': 'JERUSALEM', 'label': 'Jerusalem'}
# Hizbollah Hezbollah
# 876 {'doc_title': '92_Ceasefire', 'mention': 'Hizbollah', 'label': 'Hezbollah'}
# Israeli Israel
# 878 {'doc_title': '92_Ceasefire', 'mention': 'Israeli', 'label': 'Israel'}
# Islamic Islam
# 879 {'doc_title': '92_Ceasefire', 'mention': 'Islamic', 'label': 'Islam'}
# Israeli Israel
# 880 {'doc_title': '92_Ceasefire', 'mention': 'Israeli', 'label': 'Israel'}
# Iraqi Iraq
# 881 {'doc_title': '87_KPD', 'mention': 'Iraqi', 'label': 'Iraq'}
# Kurds Kurdistan
# 887 {'doc_title': '87_KPD', 'mention': 'Kurds', 'label': 'Kurdistan'}
# GMT Greenwich_Mean_Time
# 888 {'doc_title': '92_Ceasefire', 'mention': 'GMT', 'label': 'Greenwich_Mean_Time'}
# UNIFIL United_Nations_Interim_Force_in_Lebanon
# 889 {'doc_title': '92_Ceasefire', 'mention': 'UNIFIL', 'label': 'United_Nations_Interim_Force_in_Lebanon'}
# Lebanese Lebanon
# 891 {'doc_title': '92_Ceasefire', 'mention': 'Lebanese', 'label': 'Lebanon'}
# Hizbollah Hezbollah
# 892 {'doc_title': '92_Ceasefire', 'mention': 'Hizbollah', 'label': 'Hezbollah'}
# Israeli Israel
# 893 {'doc_title': '92_Ceasefire', 'mention': 'Israeli', 'label': 'Israel'}
# U.N. United_Nations
# 895 {'doc_title': '87_KPD', 'mention': 'U.N.', 'label': 'United_Nations'}
# Israeli Israel
# 896 {'doc_title': '92_Ceasefire', 'mention': 'Israeli', 'label': 'Israel'}
# Israeli Israel
# 898 {'doc_title': '92_Ceasefire', 'mention': 'Israeli', 'label': 'Israel'}
# Jewish Jews
# 900 {'doc_title': '92_Ceasefire', 'mention': 'Jewish', 'label': 'Jews'}
# Hizbollah Hezbollah
# 902 {'doc_title': '92_Ceasefire', 'mention': 'Hizbollah', 'label': 'Hezbollah'}
# Party of God Hezbollah
# 903 {'doc_title': '92_Ceasefire', 'mention': 'Party of God', 'label': 'Hezbollah'}
# Iraqi Iraq
# 905 {'doc_title': '87_KPD', 'mention': 'Iraqi', 'label': 'Iraq'}
# BAGHDAD Baghdad
# 906 {'doc_title': '87_KPD', 'mention': 'BAGHDAD', 'label': 'Baghdad'}
# TUNIS Tunis
# 909 {'doc_title': '93_PRESS', 'mention': 'TUNIS', 'label': 'Tunis'}
# Tunisian Tunisia
# 910 {'doc_title': '93_PRESS', 'mention': 'Tunisian', 'label': 'Tunisia'}
# Tunisian Tunisia
# 914 {'doc_title': '93_PRESS', 'mention': 'Tunisian', 'label': 'Tunisia'}
# Tunisian Tunisia
# 916 {'doc_title': '93_PRESS', 'mention': 'Tunisian', 'label': 'Tunisia'}
# LE TEMPS Le_Temps
# 918 {'doc_title': '93_PRESS', 'mention': 'LE TEMPS', 'label': 'Le_Temps'}
# Palestinian Authority Palestinian_National_Authority
# 920 {'doc_title': '93_PRESS', 'mention': 'Palestinian Authority', 'label': 'Palestinian_National_Authority'}
# Libyan Libya
# 921 {'doc_title': '93_PRESS', 'mention': 'Libyan', 'label': 'Libya'}
# U.S. United_States
# 922 {'doc_title': '94_Automakers', 'mention': 'U.S.', 'label': 'United_States'}
# DETROIT Detroit
# 923 {'doc_title': '94_Automakers', 'mention': 'DETROIT', 'label': 'Detroit'}
# Interstates 80 Interstate_80
# 926 {'doc_title': '94_Automakers', 'mention': 'Interstates 80', 'label': 'Interstate_80'}
# Midwest Midwestern_United_States
# 927 {'doc_title': '94_Automakers', 'mention': 'Midwest', 'label': 'Midwestern_United_States'}
# Belgian Belgium
# 931 {'doc_title': '95_Two', 'mention': 'Belgian', 'label': 'Belgium'}
# Belgian Belgium
# 932 {'doc_title': '95_Two', 'mention': 'Belgian', 'label': 'Belgium'}
# ROME Rome
# 933 {'doc_title': '98_Italy', 'mention': 'ROME', 'label': 'Rome'}
# Italian Italy
# 934 {'doc_title': '98_Italy', 'mention': 'Italian', 'label': 'Italy'}
# Tanzanian Tanzania
# 935 {'doc_title': '98_Italy', 'mention': 'Tanzanian', 'label': 'Tanzania'}
# Dini Lamberto_Dini
# 937 {'doc_title': '98_Italy', 'mention': 'Dini', 'label': 'Lamberto_Dini'}
# U.S. United_States
# 941 {'doc_title': '98_Italy', 'mention': 'U.S.', 'label': 'United_States'}
# Italian Italy
# 943 {'doc_title': '98_Italy', 'mention': 'Italian', 'label': 'Italy'}
# Roman Catholic Catholic_Church
# 944 {'doc_title': '98_Italy', 'mention': 'Roman Catholic', 'label': 'Catholic_Church'}
# Dini Lamberto_Dini
# 946 {'doc_title': '98_Italy', 'mention': 'Dini', 'label': 'Lamberto_Dini'}
# U.N. Security Council United_Nations_Security_Council
# 950 {'doc_title': '98_Italy', 'mention': 'U.N. Security Council', 'label': 'United_Nations_Security_Council'}

# %%
#load from dev 2 folder
# train_mentions and train_labels are same

### Read the Parsed Entity Candidate Pages...
fname2 = './Dev_set_2/parsed_candidate_entities.pickle'
parsed_entity_pages2 = pickle.load(open(fname2, 'rb'))

### Read the Mention docs...
mens_docs_file2 = "./Dev_set_2/men_docs.pickle"
men_docs2 = pickle.load(open(mens_docs_file2, 'rb'))

# load 2nd test data and label
dev_mentions_file2 = './Dev_set_2/dev2.pickle'
dev_mentions2 = pickle.load(open(dev_mentions_file2, 'rb'))

### Read the Dev Labels... (For Final Evaluation, we will replace it with the Test Data)
dev_label_file2 = './Dev_set_2/dev2_labels.pickle'
dev_labels2 = pickle.load(open(dev_label_file2, 'rb'))

# %%
## Result of the model...
result = project_part2.disambiguate_mentions(train_mentions, train_labels, dev_mentions2, men_docs2, parsed_entity_pages2)

# %%
### Read the Dev Labels... (For Final Evaluation, we will replace it with the Test Data)

accuracy = compute_accuracy(result, dev_labels2)
print("Accuracy = ", accuracy)
# Out:
# Accuracy =  0.7639751552795031

# %%
## Result of the model...
result = project_part2.disambiguate_mentions(train_mentions, train_labels, dev_mentions, men_docs, parsed_entity_pages)

# %%
## Here, we print out sample result of the model for illustration...
for key in list(result)[:5]:
    print('KEY: {} \t VAL: {}'.format(key,result[key]))

# %%
## We will be using the following function to compute the accuracy...
def compute_accuracy(result, data_labels):
    assert set(list(result.keys())) - set(list(data_labels.keys())) == set()
    TP = 0.0
    for id_ in result.keys():
        if result[id_] == data_labels[id_]['label']:
            TP +=1
    assert len(result) == len(data_labels)
    return TP/len(result)

# %%
### Read the Dev Labels... (For Final Evaluation, we will replace it with the Test Data)
dev_label_file = './Data/dev_labels.pickle'
dev_labels = pickle.load(open(dev_label_file, 'rb'))

accuracy = compute_accuracy(result, dev_labels)
print("Accuracy = ", accuracy)
# Out:
# Accuracy =  0.8697183098591549

# %% [markdown]
# ### Evaluation Metric + Scoring Function
#
# * We will compute the accuracy of your model on the `test` and/or `dev` data sets, as shown in the function: `compute_accuracy(result, data_labels)` given above. Later, we will be using the following piece-wise linear scoring function to compute your scores (0-20) for $Q2$.
#
# $$
# {
# Score(x) =\left\{
#             \begin{array}{lr}
#               0\quad x<0.70\\
#               10\cdot(20x-14) \quad 0.70 < x \leq 0.75 \\
#               10\cdot(5x-2.75) \quad 0.75 < x < 0.85 \\
#               10\cdot(12.5x-9.125) \quad 0.85 \leq x < 0.89 \\
#               20\quad x \geq 0.89
#             \end{array}
#           \right.
# }
# $$

# %% [markdown]
# ## Project Submission and Feedback
#
# For project submission, you are required to submit the following files:
#
# 1. Your implementation in a python file `project_part2.py`.
#
# 2. A report `project_part2.pdf` You need to write a concise and simple report illustrating
#     - Implementation details of $Q2$.
#     - Especially, your approach for extending your implementation in ($Q1$) for ($Q2$).
#
# **Note:** Every student will be entitled to **15 Feedback Attempts** (use them wisely), we will use the last submission for final evaluation of the **Project (part-2)**.

# %% [markdown]
# ## Bonus Points (10 points)
#
# We will award $\textbf{BONUS POINTS to the TOP-10}$ best performing students in the decreasing order of the performance on the **Project (Part-2)**, i.e., the best performing student will get 10 points, second-best will get 9 points and so on.
#
# **NOTE**:
#
# * We will not consider Project (Part-1) to award BONUS scores.
# * We will not recieve any seperate submission for the BONUS points.
# * Your project implementation for the **Part-2** will be automatically considered for the Bonus scores.
